# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
load_path = '../data/processed/tratamento_0002.csv'
df_load = pd.read_csv(load_path)

# %%
print(df_load.columns)
# Out:
# Index(['OFFER_START_DATE', 'OFFER_START_DTTM', 'OFFER_FINISH_DTTM',
#        'INVOLVED_STOCK', 'REMAINING_STOCK_AFTER_END', 'SOLD_AMOUNT',
#        'SOLD_QUANTITY', 'DOM_DOMAIN_AGG1', 'VERTICAL', 'DOMAIN_ID'],
#       dtype='object')

# %%
df_bar1 = df_load.groupby(["VERTICAL"],as_index=False)["SOLD_QUANTITY"].count().sort_values(by=["SOLD_QUANTITY"])

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
x = df_bar1["SOLD_QUANTITY"]
y = df_bar1["VERTICAL"]
plt.barh(y, x)
# Out:
# <BarContainer object of 9 artists>

# %%
df_bar2 = df_load.groupby(["VERTICAL"],as_index=False)["SOLD_AMOUNT"].count().sort_values(by=["SOLD_AMOUNT"])

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
x = df_bar2["SOLD_AMOUNT"]
y = df_bar2["VERTICAL"]
plt.barh(y, x)
# Out:
# <BarContainer object of 9 artists>

# %%
print(list(df_load.columns))
# Out:
# ['OFFER_START_DATE', 'OFFER_START_DTTM', 'OFFER_FINISH_DTTM', 'INVOLVED_STOCK', 'REMAINING_STOCK_AFTER_END', 'SOLD_AMOUNT', 'SOLD_QUANTITY', 'DOM_DOMAIN_AGG1', 'VERTICAL', 'DOMAIN_ID']

# %%
df_load.groupby(["VERTICAL", "DOM_DOMAIN_AGG1"],as_index=False)["SOLD_QUANTITY"].count()#.sort_values(by=['SOLD_QUANTITY'])
# Out:
#            VERTICAL               DOM_DOMAIN_AGG1  SOLD_QUANTITY
# 0               ACC                     ACC TOOLS             90
# 1               ACC                          AGRO              1
# 2               ACC                     AUTOPARTS           1496
# 3               ACC                     MOTOPARTS            584
# 4               ACC          VEHICULAR MULTIMEDIA             90
# 5               ACC                WHEELS & TIRES             31
# 6      APP & SPORTS                       APPAREL           3571
# 7      APP & SPORTS            APPAREL ACCESORIES           4057
# 8      APP & SPORTS                      FOOTWEAR           1406
# 9      APP & SPORTS                        SPORTS           2932
# 10     APP & SPORTS                    SUPLEMENTS            177
# 11  BEAUTY & HEALTH              BEAUTY EQUIPMENT            988
# 12  BEAUTY & HEALTH                 PERSONAL CARE           2695
# 13  BEAUTY & HEALTH                 PHARMACEUTICS           2550
# 14               CE                     COMPUTERS           3176
# 15               CE                   ELECTRONICS           2703
# 16               CE                        MOBILE           1611
# 17              CPG                     BATTERIES             86
# 18              CPG                      CLEANING            315
# 19              CPG                        DRINKS             56
# 20              CPG                         FOODS            804
# 21              CPG              PERSONAL HYGIENE            790
# 22              CPG                     PETS FOOD            335
# 23    ENTERTAINMENT  BOOKS, MULTIMEDIA & OTHER E!            457
# 24    ENTERTAINMENT           MUSICAL INSTRUMENTS             22
# 25  HOME & INDUSTRY                    HOME&DECOR           6004
# 26  HOME & INDUSTRY                      INDUSTRY           1064
# 27  HOME & INDUSTRY                      SECURITY            275
# 28  HOME & INDUSTRY                    STATIONARY           1164
# 29  HOME & INDUSTRY        TOOLS AND CONSTRUCTION           1359
# 30           OTHERS            ANTIQUES & HOBBIES              5
# 31           OTHERS                         OTHER             15
# 32           OTHERS                  PET PRODUCTS            245
# 33            T & B                          BABY            755
# 34            T & B                         PARTY            375
# 35            T & B                TOYS AND GAMES           1312

# %%
df_bar2 = df_load.groupby(["DOM_DOMAIN_AGG1"],as_index=False)["SOLD_QUANTITY"].count().sort_values(by=["SOLD_QUANTITY"])

# %%
df_bar2["DOM_DOMAIN_AGG1"].unique()
# Out:
# array(['AGRO', 'ANTIQUES & HOBBIES', 'OTHER', 'MUSICAL INSTRUMENTS',
#        'WHEELS & TIRES', 'DRINKS', 'BATTERIES', 'VEHICULAR MULTIMEDIA',
#        'ACC TOOLS', 'SUPLEMENTS', 'PET PRODUCTS', 'SECURITY', 'CLEANING',
#        'PETS FOOD', 'PARTY', 'BOOKS, MULTIMEDIA & OTHER E!', 'MOTOPARTS',
#        'BABY', 'PERSONAL HYGIENE', 'FOODS', 'BEAUTY EQUIPMENT',
#        'INDUSTRY', 'STATIONARY', 'TOYS AND GAMES',
#        'TOOLS AND CONSTRUCTION', 'FOOTWEAR', 'AUTOPARTS', 'MOBILE',
#        'PHARMACEUTICS', 'PERSONAL CARE', 'ELECTRONICS', 'SPORTS',
#        'COMPUTERS', 'APPAREL', 'APPAREL ACCESORIES', 'HOME&DECOR'],
#       dtype=object)

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
x = df_bar2["SOLD_QUANTITY"]
y = df_bar2["DOM_DOMAIN_AGG1"]
plt.barh(y, x)
# Out:
# <BarContainer object of 36 artists>

# %%
df_bar4 = df_load.groupby(["DOM_DOMAIN_AGG1"],as_index=False)["SOLD_AMOUNT"].count().sort_values(by=["SOLD_AMOUNT"])

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
x = df_bar4["SOLD_AMOUNT"]
y = df_bar4["DOM_DOMAIN_AGG1"]
plt.barh(y, x)
# Out:
# <BarContainer object of 36 artists>
