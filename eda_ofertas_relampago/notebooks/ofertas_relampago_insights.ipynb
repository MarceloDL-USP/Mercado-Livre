# %%
import pandas as pd

# %%
load_path = '../data/processed/tratamento_0002.csv'
df = pd.read_csv(load_path)

# %%
df2 = df
# Out:
#        Unnamed: 0 OFFER_START_DATE           OFFER_START_DTTM  \
# 0               0       2021-06-22  2021-06-22 16:00:00+00:00
# 1               1       2021-06-22  2021-06-22 13:00:00+00:00
# 2               2       2021-06-22  2021-06-22 07:00:00+00:00
# 3               3       2021-06-22  2021-06-22 19:00:00+00:00
# 4               4       2021-06-22  2021-06-22 13:00:00+00:00
# ...           ...              ...                        ...
# 48741       48741       2021-06-19  2021-06-19 13:00:00+00:00
# 48742       48742       2021-06-19  2021-06-19 13:00:00+00:00
# 48743       48743       2021-06-19  2021-06-19 07:00:00+00:00
# 48744       48744       2021-06-19  2021-06-19 13:00:00+00:00
# 48745       48745       2021-06-19  2021-06-19 13:00:00+00:00
#
#                OFFER_FINISH_DTTM      OFFER_TYPE  INVOLVED_STOCK  \
# 0      2021-06-22 23:02:43+00:00  lightning_deal               4
# 1      2021-06-22 19:00:02+00:00  lightning_deal               5
# ...

# %%
print(list(df2.columns.values))
# Out:
# ['OFFER_START_DATE', 'OFFER_START_DTTM', 'OFFER_FINISH_DTTM', 'INVOLVED_STOCK', 'REMAINING_STOCK_AFTER_END', 'SOLD_AMOUNT', 'SOLD_QUANTITY', 'DOM_DOMAIN_AGG1', 'VERTICAL', 'DOMAIN_ID']

# %%
values_names = ['INVOLVED_STOCK', 'REMAINING_STOCK_AFTER_END', 'SOLD_AMOUNT', 'SOLD_QUANTITY']
df3 = df2[values_names]
df3.describe()
# Out:
#        INVOLVED_STOCK  REMAINING_STOCK_AFTER_END   SOLD_AMOUNT  SOLD_QUANTITY
# count    47820.000000               47820.000000  24548.000000   24548.000000
# mean        35.153095                  30.641029     51.177417      10.861455
# std        208.339376                 197.270692    175.319125      45.502831
# min          1.000000                -192.000000      0.280000       1.000000
# 25%          5.000000                   4.000000      5.730000       1.000000
# 50%         10.000000                   8.000000     12.415000       3.000000
# 75%         15.000000                  15.000000     30.882500       6.000000
# max       9000.000000                8635.000000   4836.570000    1646.000000

# %%
df4 = df3[df3["SOLD_QUANTITY"] > 6]
df4
# Out:
#        INVOLVED_STOCK  REMAINING_STOCK_AFTER_END  SOLD_AMOUNT  SOLD_QUANTITY
# 4                  15                          0        39.65           15.0
# 7                  10                         -1       103.03           11.0
# 12                  9                          0        12.32            9.0
# 24                  8                          0         9.20            8.0
# 27                 15                          0        45.72           15.0
# ...               ...                        ...          ...            ...
# 48670              15                          7        80.66            8.0
# 48672              15                          1        21.54           14.0
# 48714              20                          1        26.62           19.0
# 48717              20                          1        24.57           19.0
# 48719              30                         -6         9.52           36.0
#
# [5337 rows x 4 columns]

# %%
df4.boxplot()
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
print(list(df2.columns.values))
# Out:
# ['OFFER_START_DATE', 'OFFER_START_DTTM', 'OFFER_FINISH_DTTM', 'INVOLVED_STOCK', 'REMAINING_STOCK_AFTER_END', 'SOLD_AMOUNT', 'SOLD_QUANTITY', 'DOM_DOMAIN_AGG1', 'VERTICAL', 'DOMAIN_ID']

# %% [markdown]
# ### Primeira coluna Data OFFER_START_DATE

# %%
type(df2['OFFER_START_DATE'][0])
# Out:
# str

# %%
df2['OFFER_START_DATE'] = pd.to_datetime(df2['OFFER_FINISH_DTTM'])

# %%
type(df2['OFFER_START_DATE'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
x = df2["OFFER_START_DATE"]
y = df2["SOLD_AMOUNT"]

plt.plot(x, y, 'o', color='black');

# %% [markdown]
# ### Segunda coluna Data OFFER_START_DTTM

# %%
type(df2['OFFER_START_DTTM'][0])
# Out:
# str

# %%
df2['OFFER_START_DTTM'] = pd.to_datetime(df2['OFFER_START_DTTM'])

# %%
type(df2['OFFER_START_DTTM'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
x = df2["OFFER_START_DTTM"]
y = df2["SOLD_AMOUNT"]

plt.plot(x, y, 'o', color='black');

# %% [markdown]
# ### Terceira coluna Data OFFER_FINISH_DTTM

# %%
type(df2['OFFER_FINISH_DTTM'][0])
# Out:
# str

# %%
df2['OFFER_FINISH_DTTM'] = pd.to_datetime(df2['OFFER_FINISH_DTTM'])

# %%
type(df2['OFFER_FINISH_DTTM'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
data = df2.query('SOLD_AMOUNT < 100')
x = data["OFFER_FINISH_DTTM"]
y = data["SOLD_AMOUNT"]

plt.plot(x, y, 'o', color='black', alpha = 0.1);

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
data = df2.query('SOLD_AMOUNT < 25')
x = data["OFFER_FINISH_DTTM"]
y = data["SOLD_AMOUNT"]

plt.plot(x, y, 'o', color='black', alpha = 0.1);

# %%
import seaborn as sns
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
sns.set_theme(style="whitegrid")
sns.violinplot(x=data["SOLD_AMOUNT"])
# Out:
# <AxesSubplot:xlabel='SOLD_AMOUNT'>

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
data = df2.query('SOLD_AMOUNT < 20')
data['SOLD_AMOUNT'].plot.hist(bins=75, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
FIGSIZE = 20
plt.figure(figsize = (FIGSIZE,FIGSIZE/2))
data = df2.query('SOLD_AMOUNT < 50')
data['SOLD_AMOUNT'].plot.hist(bins=75, alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print(list(df2.columns.values))
# Out:
# ['OFFER_START_DATE', 'OFFER_START_DTTM', 'OFFER_FINISH_DTTM', 'INVOLVED_STOCK', 'REMAINING_STOCK_AFTER_END', 'SOLD_AMOUNT', 'SOLD_QUANTITY', 'DOM_DOMAIN_AGG1', 'VERTICAL', 'DOMAIN_ID']

# %%
# sns.set_theme(style="ticks")
FIGSIZE = 20
g = sns.pairplot(df2, hue="INVOLVED_STOCK")
g.fig.set_size_inches(FIGSIZE,FIGSIZE)

# %%
# %%timeit
print(list(df2.columns.values))

# %% [markdown]
# [Overview of seaborn plotting functions](https://seaborn.pydata.org/tutorial/function_overview.html)

# %%
# %%time
sns.pairplot(data=df2)
