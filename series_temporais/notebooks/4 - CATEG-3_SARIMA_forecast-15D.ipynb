# %% [markdown]
# __Equação SARIMA__\
# Uma equação típica do modelo SARIMA se parece com o seguinte –
#
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
#
# Os parâmetros para esses tipos de modelos são os seguintes:
#
# __p__ e sazonal __P__: indicam o número de termos AR (defasagens da série estacionária)\
# __d__ e sazonal __D__: indicam diferenciações que devem ser feitas para as séries tornarem-se estacionárias\
# __q__ e __Q__ sazonal: indicam o número de termos MA (lags dos erros da previsão)\
# __lag__: indica o intervalo da sazonalidade nos dados

# %% [markdown]
# __Fazendo com que uma série temporal torne-se estacionária__
#
# Uma série temporal estacionária é aquela que não possui nenhuma tendência ou sazonalidade. É essencial lidar com qualquer tendência ou sazonalidade antes de modelar os dados da série temporal porque se as propriedades estatísticas não mudarem ao longo do tempo, torna-se mais fácil modelar os dados com precisão. Uma das maneiras populares de se fazer com que a série torne-se estacionária é __diferenciando__.

# %% [markdown]
# __Modelagem SARIMA__
#
#
# Plote a série - para verificar se há discrepâncias\
# Transforme os dados (para tornar a média e a variância constantes)\
# Aplique testes estatísticos para verificar se a série é estacionária (tanto de tendência quanto de sazonalidade)\
# Se não estacionário (ou seja, se possui tendência ou sazonalidade), torne-a estacionária diferenciando\
# Plote ACF de séries estacionárias para ordem MA, ordem MA sazonal em picos sazonais\
# Traçar PACF de séries estacionárias para ordem AR, ordem AR sazonal em picos sazonais\
# Execute SARIMA com esses parâmetros\
# Verifique a validade do modelo usando gráficos de resíduos

# %%
from datetime import datetime

t1 = datetime.now()
t1
# Out:
# datetime.datetime(2022, 4, 29, 16, 33, 17, 408443)

# %%
from constantes import *

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from joblib import Parallel # Processamento paralelo
from multiprocessing import cpu_count
from joblib import delayed

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
#define function for kpss test
from statsmodels.tsa.stattools import kpss
#define KPSS
def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
      kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# #### Carregando os dados pré-processados para o modelo

# %%
filepath = "..\data\processed\CATEG_3.csv"
df = pd.read_csv(filepath).sort_values(by = ["DATE"])
df.head(3)
# Out:
#            DATE  UNITS_SOLD
# 627  2018-09-24           0
# 735  2018-09-25           0
# 623  2018-09-27           0

# %%
df = df[df["DATE"] > "2018-10-16"]
df['DATE'] = pd.to_datetime(df['DATE'])
df['UNITS_SOLD'] = df['UNITS_SOLD'].astype(float)
df.head(3)
# Out:
#           DATE  UNITS_SOLD
# 0   2018-10-18         1.0
# 71  2018-10-19         0.0
# 396 2018-10-20         1.0

# %%
df['UNITS_SOLD'].min(), df['UNITS_SOLD'].max()
# Out:
# (0.0, 7551.0)

# %%
df['DATE'].min(), df['DATE'].max()
# Out:
# (Timestamp('2018-10-18 00:00:00'), Timestamp('2021-11-12 00:00:00'))

# %%
df.isnull().sum()
df = df.dropna()
df.isnull().sum()
# Out:
# DATE          0
# UNITS_SOLD    0
# dtype: int64

# %%
df = df.set_index('DATE')

# %% [markdown]
# #### Será definida uma reamostragem com medias semanais para a análise. Pois será mais expressiva a métrica de sazonalidade a seguir.

# %% [markdown]
# [dataframe.resample](https://www.geeksforgeeks.org/python-pandas-dataframe-resample/)

# %%
# reamostragem pela média semanal
ts_month_avg = df['UNITS_SOLD'].resample(f'{LAPSO_MEAN_3}D').mean()
ts_month_avg = ts_month_avg.dropna()
ts_month_avg = ts_month_avg.asfreq(f'{LAPSO_MEAN_3}D', method='ffill') # Incluindo uma configuração de frequência

# %%
L = len(ts_month_avg)
train_df = ts_month_avg[0:int(L*TRAINNG_DATA_PERCENTAGE_3)]
test_df = ts_month_avg[int(L*TRAINNG_DATA_PERCENTAGE_3):int(L*(TRAINNG_DATA_PERCENTAGE_3 + TEST_DATA_PERCENTAGE_3))]
validation_df = ts_month_avg[int(L*(TRAINNG_DATA_PERCENTAGE_3 + TEST_DATA_PERCENTAGE_3)):]

# %%
len(ts_month_avg)
# Out:
# 113

# %%
len(train_df) + len(test_df) + len(validation_df)
# Out:
# 113

# %% [markdown]
# __Gráfico dos dados__

# %%
train_df.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# __Identificando Variação, Tendência e Sazonalidade nos dados__\
# Vamos verificar a tendência e os componentes sazonais dos dados. Cada série temporal pode ser decomposta em 3 componentes
#
# Tendência\
# Sazonalidade\
# Ruído
#
# Vamos ver nossa série temporal decomposta –

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 18
# decomposition = sm.tsa.seasonal_decompose(train_df, model='additive')
decomposition = sm.tsa.seasonal_decompose(train_df, model='additive',period=12, extrapolate_trend = 12)
fig = decomposition.plot()
plt.show()

# %% [markdown]
# Como podemos ver, há uma tendência de alta e uma sazonalidade semestral (6 x 4 semans por mês implica um lag = 24) nos dados. Portanto, a série não é estacionária. Temos que lidar com a sazonalidade analisar o efeito. Será realizada a diferenciação e será verificado o resultado por testes estatísticos como ADF (para tendência) e OSCB (para sazonalidade).
#
# Regra de polegar para testes estatísticos -
# ADF(para tendência): se o valor p for menor que o valor crítico, a série é estacionária
# OSCB(para sazonalidade): se o valor for menor que 0,64, a série é estacionária

# %%
LAGS = int(SAZONALITY_MONTHS_3*(30/LAPSO_MEAN_3))
LAGS = int(LAGS*LAG_REDUCTION_FACTOR_3)
LAGS
# Out:
# 36

# %%
# from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# plot_acf(ts_month_avg, lags=24)
# matplotlib.pyplot.show()

# plot_pacf(ts_month_avg, lags=24)
# matplotlib.pyplot.show()

# from pylab import rcParams
# rcParams['figure.figsize'] = 18, 8
# decomposition = sm.tsa.seasonal_decompose(ts_month_avg, model='additive')
# fig = decomposition.plot()
# plt.show()

# %%
#apply adf test on the series
print(adf_test(train_df))
# print(kpss_test(ts_month_avg))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.166859
# p-value                         0.687687
# #Lags Used                      5.000000
# Number of Observations Used    84.000000
# Critical Value (1%)            -3.510712
# Critical Value (5%)            -2.896616
# Critical Value (10%)           -2.585482
# dtype: float64
# None

# %% [markdown]
# Depois de executar o teste ADF na série temporal, obtemos  __p__ = __0.112672__ que é maior que o valor crítico de 0,05. Assim podemos confirmar estatisticamente que a série não é estacionária. Portanto, podemos realizar uma diferenciação de primeira ordem para a tendência e executamos novamente o teste ADF para verificar a estacionariedade.

# %%
rcParams['figure.figsize'] = 18, 8
ts_t_adj = train_df - train_df.shift(1)
ts_t_adj = ts_t_adj.dropna()
ts_t_adj.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#apply adf test on the series
print(adf_test(ts_t_adj))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.834072
# p-value                         0.000047
# #Lags Used                      4.000000
# Number of Observations Used    84.000000
# Critical Value (1%)            -3.510712
# Critical Value (5%)            -2.896616
# Critical Value (10%)           -2.585482
# dtype: float64
# None

# %% [markdown]
# Observando o __p-value__ a __tendência__ agora parece ter desaparecido. O valor p é menor que o valor crítico de 0,05. Portanto, podemos confirmar que a série agora é uma tendência estacionária.

# %% [markdown]
# Passemos agora para a diferenciação __sazonal__. Como os dados estão mostrando uma sazonalidade semestral, realizaremos uma diferenciação com defasagem 15 dias => 12 lags.

# %%
ts_s_adj = ts_t_adj - ts_t_adj.shift(LAGS)
ts_s_adj = ts_s_adj.dropna()
ts_s_adj.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# Agora que os dados estão estacionários, vamos para a próxima etapa do processo – os gráficos ACF e PACF.
#
# Parcelas ACF e PACF
#
# Vamos tentar descobrir os parâmetos do modelo
#
# Para descobrir isso , precisaríamos traçar os gráficos ACF e PACF.
#
# ACF significa Função de Correlação Automática e PACF significa Função de Correlação Automática Parcial.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_s_adj)
matplotlib.pyplot.show()
plot_pacf(ts_s_adj)
matplotlib.pyplot.show()

# %% [markdown]
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
#
# Os parâmetros para esses tipos de modelos são os seguintes:
#
# __p__ e sazonal __P__: indicam o número de termos AR (defasagens da série estacionária)\
# __d__ e sazonal __D__: indicam diferenciações que devem ser feitas para as séries tornarem-se estacionárias\
# __q__ e __Q__ sazonal: indicam o número de termos MA (lags dos erros da previsão)\
# __lag__: indica o intervalo da sazonalidade nos dados
#
# __Estimando termos de AR, ou p__
#
# O gráfico de pirulito que você vê acima são os resultados do ACF e do PACF. Para estimar a quantidade de termos AR, você precisa olhar para o gráfico PACF. Primeiro, ignore o valor na defasagem 0. Ele sempre mostrará uma correlação perfeita, pois estamos estimando a correlação entre o valor de hoje consigo mesmo. Observe que há uma área azul no gráfico, representando o intervalo de confiança. Para estimar quantos termos de AR você deve usar, comece a contar quantos “pirulito” estão acima ou abaixo do intervalo de confiança antes que o próximo entre na área azul.
#
# p = 1
#
#
# __Estimativa de termos I, ou d__
#
# Esta é uma parte fácil. Tudo o que você precisa fazer para estimar a quantidade de I(d) termos é saber quantas diferenciações foram usadas para tornar a série estacionária. Por exemplo, se você usou diferença logarítmica ou primeira diferença para transformar uma série temporal, a quantidade de termos I será 1, pois Arauto toma a diferença entre o valor real (por exemplo, o valor de hoje) e 1 valor anterior (por exemplo, o valor de ontem).
#
# d = 1
#
# __Estimando termos de MA, ou q__
#
# Assim como a função PACF, para estimar a quantidade de termos MA, desta vez você observará o gráfico ACF. A mesma lógica é aplicada aqui: quantos pirulitos estão acima ou abaixo do intervalo de confiança antes que o próximo pirulito entre na área azul?
#
# q = 1
#
# __Estimando termos sazonais de RA, ou P__
# Caso seus dados possuam sazonalidade e você queira utilizar um modelo Sazonal ARIMA, é necessário informar os termos sazonais para AR, I e MA. O processo é bastante semelhante ao AR não sazonal, e você ainda usará a função ACF e PACF para isso. Para estimar a quantidade de termos AR, você examinará mais uma vez a função PACF. Agora, em vez de contar quantos pirulitos estão fora do intervalo de confiança, você contará quantos pirulitos sazonais estão fora.
#
# Como os dados possuem sazonalidade semestral, é preciso verificar se o “pirulito” na defasagem 6 está fora da área do intervalo de confiança. Em caso de resultado positivo, é necessário adicionar 1 termo para AR Sazonal. Como temos um pirulito negativo na posição 6 adicionamos 1.
#
# P = 0
#
# __Estimating Seasonal I terms__
#
# A mesma lógica de estimar a diferenciação não sazonal é aplicada aqui. Se você usou a diferenciação sazonal para tornar a série temporal estacionária (por exemplo, o valor real (Yt) subtraído por 12 meses anteriores (Yt-12)), você adicionará 1 termo à diferenciação sazonal.
#
# D = 1
#
# __Estimating Seasonal MA terms__
#
# Para a média móvel sazonal (SMA), estaremos olhando para o gráfico ACF e usaremos a mesma lógica de estimar os termos SAR.
# Como só temos uma correlação forte em 4 temos, estimamos que o valor deve ser 0 ou 1.
#
# Q = 0
#
# lag = 18
#
# Portanto,
#
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
# $SARIMA(0,1,0)\times(1,1,1)_{26}$

# %%
p = range(0, 3)
d = range(0, 3)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = []
for x in list(itertools.product(p, d, q)):
    seasonal_pdq.append((x[0], x[1], x[2], 12) )

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
TOTAL_TEST = len(pdq)*len(seasonal_pdq)
print(f"Serão realizado {TOTAL_TEST} testes no total.")
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 0, 2, 12)
# SARIMAX: (0, 0, 2) x (0, 1, 0, 12)
# Serão realizado 729 testes no total.

# %%
# executor = Parallel(n_jobs=cpu_count(), backend='multiprocessing')

# scores = executor(tasks)

# %%
from operator import itemgetter
params_list = []
params_list_top = []
cont = 0
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_df,
                                            order= param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            # param = (1, 1, 1)
            cont +=1
            print(f"Teste {cont}/{TOTAL_TEST}")
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            params_list.append([param, param_seasonal, results.aic])
            params_list_sort = []
            params_list_sort = sorted(params_list, key=itemgetter(2))
            params_list_sort_1 = params_list_sort[0]
            params_list_sort_2 = params_list_sort[2]
            params_list_sort_3 = params_list_sort[3]
            params_list_sort_4 = params_list_sort[4]
            params_list_sort_5 = params_list_sort[5]
            print(f'TOP 1 SARIMA params: {params_list_sort_1[0]}x{params_list_sort_1[1]}12 - AIC:{params_list_sort_1[2]}')
            print(f'TOP 2 SARIMA params: {params_list_sort_2[0]}x{params_list_sort_2[1]}12 - AIC:{params_list_sort_2[2]}')
            print(f'TOP 3 SARIMA params: {params_list_sort_3[0]}x{params_list_sort_3[1]}12 - AIC:{params_list_sort_3[2]}')
            print(f'TOP 4 SARIMA params: {params_list_sort_4[0]}x{params_list_sort_4[1]}12 - AIC:{params_list_sort_4[2]}')
            print(f'TOP 5 SARIMA params: {params_list_sort_5[0]}x{params_list_sort_5[1]}12 - AIC:{params_list_sort_5[2]}')
        except:
            continue

params_list_sort = []
params_list_sort = sorted(params_list, key=itemgetter(2))[0]
print(f'Best SARIMA params: {params_list_sort[0]}x{params_list_sort[1]}12 - AIC:{params_list_sort[2]}')
# Out:
# Optimization terminated successfully.
#          Current function value: 8.567208
#          Iterations: 1
#          Function evaluations: 18
# Teste 1/729
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1544.09737134268
# Optimization terminated successfully.
#          Current function value: 8.278916
#          Iterations: 3
#          Function evaluations: 84
# Teste 2/729
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1494.2049224240425
# Optimization terminated successfully.
#          Current function value: 8.123537
#          Iterations: 4
#          Function evaluations: 166
# Teste 3/729
# ARIMA(0, 0, 0)x(0, 0, 2, 12)12 - AIC:1468.23667875625
# Optimization terminated successfully.
#          Current function value: 6.836925
#          Iterations: 2
#          Function evaluations: 48
# Teste 4/729
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# Optimization terminated successfully.
#          Current function value: 6.836925
#          Iterations: 2
#          Function evaluations: 44
# Teste 5/729
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# Optimization terminated successfully.
#          Current function value: 6.825897
#          Iterations: 3
#          Function evaluations: 124
# Teste 6/729
# ARIMA(0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# TOP 3 SARIMA params: (0, 0, 0)x(0, 0, 2, 12)12 - AIC:1468.23667875625
# TOP 4 SARIMA params: (0, 0, 0)x(0, 0, 1, 12)12 - AIC:1494.2049224240425
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 0, 12)12 - AIC:1544.09737134268
# Optimization terminated successfully.
#          Current function value: 6.026500
#          Iterations: 2
#          Function evaluations: 35
# Teste 7/729
# ARIMA(0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# TOP 4 SARIMA params: (0, 0, 0)x(0, 0, 2, 12)12 - AIC:1468.23667875625
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 1, 12)12 - AIC:1494.2049224240425
# Optimization terminated successfully.
#          Current function value: 5.823838
#          Iterations: 4
#          Function evaluations: 106
# Teste 8/729
# ARIMA(0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 2, 12)12 - AIC:1468.23667875625
# Optimization terminated successfully.
#          Current function value: 5.738971
#          Iterations: 4
#          Function evaluations: 155
# Teste 9/729
# ARIMA(0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# Optimization terminated successfully.
#          Current function value: 7.984741
#          Iterations: 2
#          Function evaluations: 59
# Teste 10/729
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1441.253374217381
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# Optimization terminated successfully.
#          Current function value: 7.984514
#          Iterations: 4
#          Function evaluations: 157
# Teste 11/729
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1443.212601272902
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# Optimization terminated successfully.
#          Current function value: 7.977410
#          Iterations: 4
#          Function evaluations: 200
# Teste 12/729
# ARIMA(0, 0, 0)x(1, 0, 2, 12)12 - AIC:1443.9337667304649
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 2, 12)12 - AIC:1234.661391919569
# Optimization terminated successfully.
#          Current function value: 6.836924
#          Iterations: 2
#          Function evaluations: 44
# Teste 13/729
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:1234.6464068527475
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 0, 12)12 - AIC:1234.6464068527475
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# Optimization terminated successfully.
#          Current function value: 6.834468
#          Iterations: 2
#          Function evaluations: 67
# Teste 14/729
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1236.2041970198952
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 0, 12)12 - AIC:1234.6464068527475
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 1, 12)12 - AIC:1234.646433684709
# Optimization terminated successfully.
#          Current function value: 6.738855
#          Iterations: 8
#          Function evaluations: 410
# Teste 15/729
# ARIMA(0, 0, 0)x(1, 1, 2, 12)12 - AIC:1220.9939817659244
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 2, 12)12 - AIC:1220.9939817659244
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 0, 12)12 - AIC:1234.6464068527475
# Optimization terminated successfully.
#          Current function value: 5.900941
#          Iterations: 2
#          Function evaluations: 47
# Teste 16/729
# ARIMA(0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 2, 12)12 - AIC:1220.9939817659244
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 12)12 - AIC:1232.646516647238
# Optimization terminated successfully.
#          Current function value: 5.776633
#          Iterations: 5
#          Function evaluations: 187
# Teste 17/729
# ARIMA(0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 4 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 2, 12)12 - AIC:1220.9939817659244
# Optimization terminated successfully.
#          Current function value: 5.750855
#          Iterations: 4
#          Function evaluations: 204
# Teste 18/729
# ARIMA(0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# Optimization terminated successfully.
#          Current function value: 7.984428
#          Iterations: 2
#          Function evaluations: 80
# Teste 19/729
# ARIMA(0, 0, 0)x(2, 0, 0, 12)12 - AIC:1443.196952080663
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# Optimization terminated successfully.
#          Current function value: 7.982318
#          Iterations: 2
#          Function evaluations: 98
# Teste 20/729
# ARIMA(0, 0, 0)x(2, 0, 1, 12)12 - AIC:1444.8172110745559
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# Optimization terminated successfully.
#          Current function value: 7.977472
#          Iterations: 3
#          Function evaluations: 180
# Teste 21/729
# ARIMA(0, 0, 0)x(2, 0, 2, 12)12 - AIC:1445.944974179137
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# Optimization terminated successfully.
#          Current function value: 6.826149
#          Iterations: 2
#          Function evaluations: 66
# Teste 22/729
# ARIMA(0, 0, 0)x(2, 1, 0, 12)12 - AIC:1234.7068103498602
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# Optimization terminated successfully.
#          Current function value: 6.774548
#          Iterations: 6
#          Function evaluations: 290
# Teste 23/729
# ARIMA(0, 0, 0)x(2, 1, 1, 12)12 - AIC:1227.418626251064
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# Optimization terminated successfully.
#          Current function value: 6.738237
#          Iterations: 10
#          Function evaluations: 682
# Teste 24/729
# ARIMA(0, 0, 0)x(2, 1, 2, 12)12 - AIC:1222.8826506900102
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 0, 12)12 - AIC:1086.770074714171
# Optimization terminated successfully.
#          Current function value: 5.784409
#          Iterations: 3
#          Function evaluations: 107
# Teste 25/729
# ARIMA(0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 3 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# TOP 4 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 0, 12)12 - AIC:1066.1693026851692
# Optimization terminated successfully.
#          Current function value: 5.736238
#          Iterations: 4
#          Function evaluations: 201
# Teste 26/729
# ARIMA(0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 1 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 2 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 1, 12)12 - AIC:1052.2907957271775
# Optimization terminated successfully.
#          Current function value: 5.704555
#          Iterations: 8
#          Function evaluations: 500
# Teste 27/729
# ARIMA(0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 8.004322
#          Iterations: 2
#          Function evaluations: 53
# Teste 28/729
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1444.7780031509128
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 7.774006
#          Iterations: 3
#          Function evaluations: 120
# Teste 29/729
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:1405.3211172913798
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 7.645549
#          Iterations: 4
#          Function evaluations: 198
# Teste 30/729
# ARIMA(0, 0, 1)x(0, 0, 2, 12)12 - AIC:1384.1987755000864
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 6.504216
#          Iterations: 2
#          Function evaluations: 46
# Teste 31/729
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:1174.758874630451
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 6.498343
#          Iterations: 2
#          Function evaluations: 66
# Teste 32/729
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1175.7016794338736
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 6.488834
#          Iterations: 3
#          Function evaluations: 137
# Teste 33/729
# ARIMA(0, 0, 1)x(0, 1, 2, 12)12 - AIC:1175.9902066375041
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 5.797888
#          Iterations: 2
#          Function evaluations: 46
# Teste 34/729
# ARIMA(0, 0, 1)x(0, 2, 0, 12)12 - AIC:1047.6199166438848
# TOP 1 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 3 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 0, 12)12 - AIC:1047.1936136472114
# Optimization terminated successfully.
#          Current function value: 5.588483
#          Iterations: 3
#          Function evaluations: 116
# Teste 35/729
# ARIMA(0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 2 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 3 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 4 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 1, 12)12 - AIC:1045.793982650322
# Optimization terminated successfully.
#          Current function value: 5.520177
#          Iterations: 5
#          Function evaluations: 245
# Teste 36/729
# ARIMA(0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# Optimization terminated successfully.
#          Current function value: 7.564938
#          Iterations: 4
#          Function evaluations: 171
# Teste 37/729
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1367.6888188850573
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# Optimization terminated successfully.
#          Current function value: 7.562931
#          Iterations: 5
#          Function evaluations: 260
# Teste 38/729
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:1369.3275539097772
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# Optimization terminated successfully.
#          Current function value: 7.557036
#          Iterations: 4
#          Function evaluations: 260
# Teste 39/729
# ARIMA(0, 0, 1)x(1, 0, 2, 12)12 - AIC:1370.266474173927
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# Optimization terminated successfully.
#          Current function value: 6.496836
#          Iterations: 2
#          Function evaluations: 66
# Teste 40/729
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:1175.4305680857365
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# Optimization terminated successfully.
#          Current function value: 6.501018
#          Iterations: 3
#          Function evaluations: 138
# Teste 41/729
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:1178.183221871366
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# Optimization terminated successfully.
#          Current function value: 6.492044
#          Iterations: 3
#          Function evaluations: 168
# Teste 42/729
# ARIMA(0, 0, 1)x(1, 1, 2, 12)12 - AIC:1178.567911130932
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 3 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# TOP 5 SARIMA params: (0, 0, 0)x(1, 2, 2, 12)12 - AIC:1043.1538501297694
# Optimization terminated successfully.
#          Current function value: 5.652124
#          Iterations: 3
#          Function evaluations: 116
# Teste 43/729
# ARIMA(0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 3 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 4 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 1, 12)12 - AIC:1040.5229061602734
# Optimization terminated successfully.
#          Current function value: 5.544705
#          Iterations: 4
#          Function evaluations: 199
# Teste 44/729
# ARIMA(0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 4 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# TOP 5 SARIMA params: (0, 0, 0)x(0, 2, 2, 12)12 - AIC:1039.0148143267857
# Optimization terminated successfully.
#          Current function value: 5.529440
#          Iterations: 5
#          Function evaluations: 316
# Teste 45/729
# ARIMA(0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# Optimization terminated successfully.
#          Current function value: 7.562361
#          Iterations: 4
#          Function evaluations: 215
# Teste 46/729
# ARIMA(0, 0, 1)x(2, 0, 0, 12)12 - AIC:1369.224996174066
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# Optimization terminated successfully.
#          Current function value: 7.563797
#          Iterations: 4
#          Function evaluations: 262
# Teste 47/729
# ARIMA(0, 0, 1)x(2, 0, 1, 12)12 - AIC:1371.4833718875022
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# Optimization terminated successfully.
#          Current function value: 7.557674
#          Iterations: 4
#          Function evaluations: 307
# Teste 48/729
# ARIMA(0, 0, 1)x(2, 0, 2, 12)12 - AIC:1372.3813134142288
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# Optimization terminated successfully.
#          Current function value: 6.491831
#          Iterations: 3
#          Function evaluations: 134
# Teste 49/729
# ARIMA(0, 0, 1)x(2, 1, 0, 12)12 - AIC:1176.529658860853
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# Optimization terminated successfully.
#          Current function value: 6.464513
#          Iterations: 8
#          Function evaluations: 466
# Teste 50/729
# ARIMA(0, 0, 1)x(2, 1, 1, 12)12 - AIC:1173.6122581916752
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# Optimization terminated successfully.
#          Current function value: 6.491365
#          Iterations: 2
#          Function evaluations: 137
# Teste 51/729
# ARIMA(0, 0, 1)x(2, 1, 2, 12)12 - AIC:1180.4456265148508
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# TOP 5 SARIMA params: (0, 0, 0)x(2, 2, 2, 12)12 - AIC:1036.8198842163126
# Optimization terminated successfully.
#          Current function value: 5.572379
#          Iterations: 4
#          Function evaluations: 187
# Teste 52/729
# ARIMA(0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 0, 12)12 - AIC:1023.3823596172963
# Optimization terminated successfully.
#          Current function value: 5.525636
#          Iterations: 5
#          Function evaluations: 313
# Teste 53/729
# ARIMA(0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# TOP 5 SARIMA params: (0, 0, 1)x(0, 2, 1, 12)12 - AIC:1011.9269141732296
# Optimization terminated successfully.
#          Current function value: 5.523631
#          Iterations: 6
#          Function evaluations: 443
# Teste 54/729
# ARIMA(0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 7.627350
#          Iterations: 3
#          Function evaluations: 124
# Teste 55/729
# ARIMA(0, 0, 2)x(0, 0, 0, 12)12 - AIC:1378.9229756195934
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 7.509186
#          Iterations: 4
#          Function evaluations: 209
# Teste 56/729
# ARIMA(0, 0, 2)x(0, 0, 1, 12)12 - AIC:1359.6534784771318
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 7.411416
#          Iterations: 4
#          Function evaluations: 260
# Teste 57/729
# ARIMA(0, 0, 2)x(0, 0, 2, 12)12 - AIC:1344.0548409520547
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 6.391067
#          Iterations: 3
#          Function evaluations: 99
# Teste 58/729
# ARIMA(0, 0, 2)x(0, 1, 0, 12)12 - AIC:1156.39200066145
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 6.364531
#          Iterations: 3
#          Function evaluations: 136
# Teste 59/729
# ARIMA(0, 0, 2)x(0, 1, 1, 12)12 - AIC:1153.6155610962455
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 6.347429
#          Iterations: 3
#          Function evaluations: 164
# Teste 60/729
# ARIMA(0, 0, 2)x(0, 1, 2, 12)12 - AIC:1152.5372476368627
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 5.736764
#          Iterations: 3
#          Function evaluations: 102
# Teste 61/729
# ARIMA(0, 0, 2)x(0, 2, 0, 12)12 - AIC:1038.6174807258162
# TOP 1 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 2 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 0, 12)12 - AIC:1011.0281729573247
# Optimization terminated successfully.
#          Current function value: 5.519011
#          Iterations: 4
#          Function evaluations: 186
# Teste 62/729
# ARIMA(0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 2 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 3 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 2, 12)12 - AIC:1006.2535412319058
# Optimization terminated successfully.
#          Current function value: 5.448247
#          Iterations: 5
#          Function evaluations: 307
# Teste 63/729
# ARIMA(0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 7.385422
#          Iterations: 5
#          Function evaluations: 273
# Teste 64/729
# ARIMA(0, 0, 2)x(1, 0, 0, 12)12 - AIC:1337.3759167
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 7.370798
#          Iterations: 5
#          Function evaluations: 320
# Teste 65/729
# ARIMA(0, 0, 2)x(1, 0, 1, 12)12 - AIC:1336.7435781183694
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 7.358444
#          Iterations: 5
#          Function evaluations: 373
# Teste 66/729
# ARIMA(0, 0, 2)x(1, 0, 2, 12)12 - AIC:1336.5200032772125
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 6.356398
#          Iterations: 3
#          Function evaluations: 132
# Teste 67/729
# ARIMA(0, 0, 2)x(1, 1, 0, 12)12 - AIC:1152.1516324774984
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 6.354984
#          Iterations: 5
#          Function evaluations: 284
# Teste 68/729
# ARIMA(0, 0, 2)x(1, 1, 1, 12)12 - AIC:1153.897035626474
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 6.353122
#          Iterations: 3
#          Function evaluations: 204
# Teste 69/729
# ARIMA(0, 0, 2)x(1, 1, 2, 12)12 - AIC:1155.5618809428508
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 5.564242
#          Iterations: 3
#          Function evaluations: 139
# Teste 70/729
# ARIMA(0, 0, 2)x(1, 2, 0, 12)12 - AIC:1009.5635068191044
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 3 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 4 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 1, 12)12 - AIC:1006.0469784346488
# Optimization terminated successfully.
#          Current function value: 5.465959
#          Iterations: 4
#          Function evaluations: 254
# Teste 71/729
# ARIMA(0, 0, 2)x(1, 2, 1, 12)12 - AIC:993.8726857609529
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 3 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 4 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# TOP 5 SARIMA params: (0, 0, 1)x(1, 2, 2, 12)12 - AIC:1005.2992277384874
# Optimization terminated successfully.
#          Current function value: 5.457438
#          Iterations: 6
#          Function evaluations: 431
# Teste 72/729
# ARIMA(0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# Optimization terminated successfully.
#          Current function value: 7.364733
#          Iterations: 5
#          Function evaluations: 322
# Teste 73/729
# ARIMA(0, 0, 2)x(2, 0, 0, 12)12 - AIC:1335.6519373140638
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# Optimization terminated successfully.
#          Current function value: 7.368295
#          Iterations: 5
#          Function evaluations: 381
# Teste 74/729
# ARIMA(0, 0, 2)x(2, 0, 1, 12)12 - AIC:1338.2931465473314
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# Optimization terminated successfully.
#          Current function value: 7.359362
#          Iterations: 5
#          Function evaluations: 425
# Teste 75/729
# ARIMA(0, 0, 2)x(2, 0, 2, 12)12 - AIC:1338.6852412217047
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# Optimization terminated successfully.
#          Current function value: 6.354134
#          Iterations: 3
#          Function evaluations: 167
# Teste 76/729
# ARIMA(0, 0, 2)x(2, 1, 0, 12)12 - AIC:1153.744091953372
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# Optimization terminated successfully.
#          Current function value: 6.351103
#          Iterations: 3
#          Function evaluations: 201
# Teste 77/729
# ARIMA(0, 0, 2)x(2, 1, 1, 12)12 - AIC:1155.1984838315782
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# Optimization terminated successfully.
#          Current function value: 6.353611
#          Iterations: 3
#          Function evaluations: 233
# Teste 78/729
# ARIMA(0, 0, 2)x(2, 1, 2, 12)12 - AIC:1157.6499556539102
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 4 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# TOP 5 SARIMA params: (0, 0, 1)x(2, 2, 1, 12)12 - AIC:1004.6145683248416
# Optimization terminated successfully.
#          Current function value: 5.488197
#          Iterations: 4
#          Function evaluations: 230
# Teste 79/729
# ARIMA(0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 3 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# TOP 4 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# TOP 5 SARIMA params: (0, 0, 1)x(0, 2, 2, 12)12 - AIC:1001.6318391077269
# Optimization terminated successfully.
#          Current function value: 5.455983
#          Iterations: 5
#          Function evaluations: 363
# Teste 80/729
# ARIMA(0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# TOP 5 SARIMA params: (0, 0, 2)x(0, 2, 1, 12)12 - AIC:1001.4220071720576
# Optimization terminated successfully.
#          Current function value: 5.459035
#          Iterations: 5
#          Function evaluations: 421
# Teste 81/729
# ARIMA(0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 6.873476
#          Iterations: 1
#          Function evaluations: 10
# Teste 82/729
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1239.2257479252419
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 6.872941
#          Iterations: 2
#          Function evaluations: 42
# Teste 83/729
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1241.1294645133612
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 6.872941
#          Iterations: 2
#          Function evaluations: 66
# Teste 84/729
# ARIMA(0, 1, 0)x(0, 0, 2, 12)12 - AIC:1243.1293534320798
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 6.242302
#          Iterations: 2
#          Function evaluations: 38
# Teste 85/729
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:1125.6143943216227
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 6.085455
#          Iterations: 3
#          Function evaluations: 76
# Teste 86/729
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1099.3819448060224
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 6.085021
#          Iterations: 3
#          Function evaluations: 121
# Teste 87/729
# ARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:1101.3038132282372
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 5.649993
#          Iterations: 2
#          Function evaluations: 40
# Teste 88/729
# ARIMA(0, 1, 0)x(0, 2, 0, 12)12 - AIC:1018.9987780025984
# TOP 1 SARIMA params: (0, 0, 2)x(0, 2, 2, 12)12 - AIC:990.6844724527577
# TOP 2 SARIMA params: (0, 0, 2)x(2, 2, 1, 12)12 - AIC:994.0769474975355
# TOP 3 SARIMA params: (0, 0, 2)x(1, 2, 2, 12)12 - AIC:994.3388501033772
# TOP 4 SARIMA params: (0, 0, 2)x(2, 2, 2, 12)12 - AIC:996.6262344729735
# TOP 5 SARIMA params: (0, 0, 2)x(2, 2, 0, 12)12 - AIC:997.8755151565949
# Optimization terminated successfully.
#          Current function value: 5.427315
#          Iterations: 3
# ...
# Optimization terminated successfully.
#          Current function value: 5.295011
#          Iterations: 7
#          Function evaluations: 669
# Teste 701/729
# ARIMA(2, 2, 1)x(2, 2, 1, 12)12 - AIC:967.1020142101067
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.289654
#          Iterations: 15
#          Function evaluations: 1452
# Teste 702/729
# ARIMA(2, 2, 1)x(2, 2, 2, 12)12 - AIC:968.1377838765377
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.791275
#          Iterations: 7
#          Function evaluations: 494
# Teste 703/729
# ARIMA(2, 2, 2)x(0, 0, 0, 12)12 - AIC:1232.4294509414344
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.791016
#          Iterations: 6
#          Function evaluations: 490
# Teste 704/729
# ARIMA(2, 2, 2)x(0, 0, 1, 12)12 - AIC:1234.382863605384
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.790223
#          Iterations: 6
#          Function evaluations: 558
# Teste 705/729
# ARIMA(2, 2, 2)x(0, 0, 2, 12)12 - AIC:1236.2402198471334
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.213638
#          Iterations: 2
#          Function evaluations: 118
# Teste 706/729
# ARIMA(2, 2, 2)x(0, 1, 0, 12)12 - AIC:1128.4548565788766
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.023013
#          Iterations: 7
#          Function evaluations: 517
# Teste 707/729
# ARIMA(2, 2, 2)x(0, 1, 1, 12)12 - AIC:1096.1423606562314
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.023586
#          Iterations: 7
#          Function evaluations: 597
# Teste 708/729
# ARIMA(2, 2, 2)x(0, 1, 2, 12)12 - AIC:1098.2454127185813
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.579552
#          Iterations: 5
#          Function evaluations: 306
# Teste 709/729
# ARIMA(2, 2, 2)x(0, 2, 0, 12)12 - AIC:1014.3194040655043
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.352964
#          Iterations: 7
#          Function evaluations: 558
# Teste 710/729
# ARIMA(2, 2, 2)x(0, 2, 1, 12)12 - AIC:975.5335841538624
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.286885
#          Iterations: 7
#          Function evaluations: 637
# Teste 711/729
# ARIMA(2, 2, 2)x(0, 2, 2, 12)12 - AIC:965.6393169328035
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.790803
#          Iterations: 7
#          Function evaluations: 573
# Teste 712/729
# ARIMA(2, 2, 2)x(1, 0, 0, 12)12 - AIC:1234.3446007681155
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.789994
#          Iterations: 6
#          Function evaluations: 560
# Teste 713/729
# ARIMA(2, 2, 2)x(1, 0, 1, 12)12 - AIC:1236.1989462662468
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.790820
#          Iterations: 5
#          Function evaluations: 544
# Teste 714/729
# ARIMA(2, 2, 2)x(1, 0, 2, 12)12 - AIC:1238.3476591930976
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.075966
#          Iterations: 6
#          Function evaluations: 525
# Teste 715/729
# ARIMA(2, 2, 2)x(1, 1, 0, 12)12 - AIC:1105.6739502289743
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.023165
#          Iterations: 7
#          Function evaluations: 603
# Teste 716/729
# ARIMA(2, 2, 2)x(1, 1, 1, 12)12 - AIC:1098.1696857467446
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.023654
#          Iterations: 6
#          Function evaluations: 665
# Teste 717/729
# ARIMA(2, 2, 2)x(1, 1, 2, 12)12 - AIC:1100.2578010619275
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.420614
#          Iterations: 3
#          Function evaluations: 218
# Teste 718/729
# ARIMA(2, 2, 2)x(1, 2, 0, 12)12 - AIC:987.7105859300682
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.303974
#          Iterations: 8
#          Function evaluations: 669
# Teste 719/729
# ARIMA(2, 2, 2)x(1, 2, 1, 12)12 - AIC:968.7153250282936
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.286152
#          Iterations: 12
#          Function evaluations: 1226
# Teste 720/729
# ARIMA(2, 2, 2)x(1, 2, 2, 12)12 - AIC:967.5073001288807
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.790188
#          Iterations: 5
#          Function evaluations: 427
# Teste 721/729
# ARIMA(2, 2, 2)x(2, 0, 0, 12)12 - AIC:1236.2338852985774
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.790592
#          Iterations: 6
#          Function evaluations: 647
# Teste 722/729
# ARIMA(2, 2, 2)x(2, 0, 1, 12)12 - AIC:1238.3066441313413
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.790041
#          Iterations: 7
#          Function evaluations: 801
# Teste 723/729
# ARIMA(2, 2, 2)x(2, 0, 2, 12)12 - AIC:1240.2074302971996
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.044125
#          Iterations: 6
#          Function evaluations: 590
# Teste 724/729
# ARIMA(2, 2, 2)x(2, 1, 0, 12)12 - AIC:1101.942451117028
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.023892
#          Iterations: 6
#          Function evaluations: 649
# Teste 725/729
# ARIMA(2, 2, 2)x(2, 1, 1, 12)12 - AIC:1100.3006228868555
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 6.023379
#          Iterations: 6
#          Function evaluations: 653
# Teste 726/729
# ARIMA(2, 2, 2)x(2, 1, 2, 12)12 - AIC:1102.2081811353257
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.343376
#          Iterations: 6
#          Function evaluations: 575
# Teste 727/729
# ARIMA(2, 2, 2)x(2, 2, 0, 12)12 - AIC:975.8076809283509
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.291590
#          Iterations: 7
#          Function evaluations: 699
# Teste 728/729
# ARIMA(2, 2, 2)x(2, 2, 1, 12)12 - AIC:968.4861476517128
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Optimization terminated successfully.
#          Current function value: 5.299213
#          Iterations: 7
#          Function evaluations: 775
# Teste 729/729
# ARIMA(2, 2, 2)x(2, 2, 2, 12)12 - AIC:971.8583801220257
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Best SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0

# %% [markdown]
# ````
# Teste 729/729
# ARIMA(2, 2, 2)x(2, 2, 2, 12)12 - AIC:971.8583801220257
# TOP 1 SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# TOP 2 SARIMA params: (0, 2, 2)x(0, 2, 2, 12)12 - AIC:963.721620897012
# TOP 3 SARIMA params: (1, 2, 1)x(0, 2, 2, 12)12 - AIC:963.7725456480041
# TOP 4 SARIMA params: (0, 2, 1)x(1, 2, 2, 12)12 - AIC:963.9585804384242
# TOP 5 SARIMA params: (0, 2, 1)x(1, 2, 1, 12)12 - AIC:964.3414074786426
# Best SARIMA params: (0, 2, 0)x(2, 1, 2, 12)12 - AIC:10.0
# ````

# %%
mod = sm.tsa.statespace.SARIMAX(train_df,
                                order=(0, 2, 0),
                                seasonal_order=(2, 1, 2, LAGS))
results = mod.fit(method = 'powell')
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 4.438845
#          Iterations: 2
#          Function evaluations: 123
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L36      -0.5442   1.22e+06  -4.45e-07      1.000    -2.4e+06     2.4e+06
# ar.S.L72      -0.0927   4.38e+05  -2.12e-07      1.000   -8.57e+05    8.57e+05
# ma.S.L36       0.0050   1.22e+06   4.12e-09      1.000    -2.4e+06     2.4e+06
# ma.S.L72      -0.0031   2.21e+05  -1.39e-08      1.000   -4.33e+05    4.33e+05
# sigma2       2.45e+05   1.28e+04     19.214      0.000     2.2e+05     2.7e+05
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
train_df.min(), train_df.max()
# Out:
# (0.0, 3446.2)

# %%
ts_month_avg.index.min(), ts_month_avg.index.max()
# Out:
# (Timestamp('2018-10-18 00:00:00', freq='10D'),
#  Timestamp('2021-11-11 00:00:00', freq='10D'))

# %%
ts_month_avg.min(), ts_month_avg.max()
# Out:
# (0.0, 5061.5)

# %%
train_df = ts_month_avg[0:int(L*0.80)]
test_df = ts_month_avg[int(L*0.80):int(L*0.90)]
validation_df = ts_month_avg[int(L*0.90):]

# %%
train_df.index.min(), train_df.index.max()
# Out:
# (Timestamp('2018-10-18 00:00:00', freq='10D'),
#  Timestamp('2021-03-26 00:00:00', freq='10D'))

# %%
test_df.index.min(), test_df.index.max()
# Out:
# (Timestamp('2021-04-05 00:00:00', freq='10D'),
#  Timestamp('2021-07-14 00:00:00', freq='10D'))

# %%
validation_df.index.min(), validation_df.index.max()
# Out:
# (Timestamp('2021-07-24 00:00:00', freq='10D'),
#  Timestamp('2021-11-11 00:00:00', freq='10D'))

# %%
START_TIME_PREDICTION = train_df.index.max()
START_TIME_PREDICTION
# Out:
# Timestamp('2021-03-26 00:00:00', freq='10D')

# %%
import datetime
END_TIME_PREDICTION = validation_df.index.max() + datetime.timedelta(days=+120)
END_TIME_PREDICTION = END_TIME_PREDICTION
END_TIME_PREDICTION
# Out:
# Timestamp('2022-03-11 00:00:00', freq='10D')

# %%
pred = results.get_prediction(start=START_TIME_PREDICTION, dynamic=True, end=END_TIME_PREDICTION)
pred_ci = pred.conf_int(alpha=0.05)
ax = ts_month_avg.plot(label='Dados Originais', color = "blue")
ax = train_df.plot(label='Dados Treino', color = "green")
pred.predicted_mean.plot(ax=ax, label='Previsão', alpha=.7, figsize=(14, 4), color = "red")
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('DATE')
ax.set_ylabel('UNITS_SOLD')
plt.ylim([1000, 4000])

TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS = 6

TIME_INTERAVAL_TO_OBSERVE = TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS*7
 
plt.xlim([START_TIME_PREDICTION + datetime.timedelta(days=-TIME_INTERAVAL_TO_OBSERVE/8), START_TIME_PREDICTION + datetime.timedelta(days=TIME_INTERAVAL_TO_OBSERVE)])
plt.title(f"Previsão para {TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS} semanas.")
plt.legend()
plt.show()

# %%
from datetime import datetime
t2 = datetime.now()
dt = t2 - t1
print(f"O tempo total para rodar o sript foi de {dt}")
# Out:
# O tempo total para rodar o sript foi de 0:07:21.710088
