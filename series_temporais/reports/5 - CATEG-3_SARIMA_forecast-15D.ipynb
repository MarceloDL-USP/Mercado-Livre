# %% [markdown]
# __Equação SARIMA__\
# Uma equação típica do modelo SARIMA se parece com o seguinte –
#
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
#
# Os parâmetros para esses tipos de modelos são os seguintes:
#
# __p__ e sazonal __P__: indicam o número de termos AR (defasagens da série estacionária)\
# __d__ e sazonal __D__: indicam diferenciações que devem ser feitas para as séries tornarem-se estacionárias\
# __q__ e __Q__ sazonal: indicam o número de termos MA (lags dos erros da previsão)\
# __lag__: indica o intervalo da sazonalidade nos dados

# %% [markdown]
# __Fazendo com que uma série temporal torne-se estacionária__
#
# Uma série temporal estacionária é aquela que não possui nenhuma tendência ou sazonalidade. É essencial lidar com qualquer tendência ou sazonalidade antes de modelar os dados da série temporal porque se as propriedades estatísticas não mudarem ao longo do tempo, torna-se mais fácil modelar os dados com precisão. Uma das maneiras populares de se fazer com que a série torne-se estacionária é __diferenciando__.

# %% [markdown]
# __Modelagem SARIMA__
#
#
# Plote a série - para verificar se há discrepâncias\
# Transforme os dados (para tornar a média e a variância constantes)\
# Aplique testes estatísticos para verificar se a série é estacionária (tanto de tendência quanto de sazonalidade)\
# Se não estacionário (ou seja, se possui tendência ou sazonalidade), torne-a estacionária diferenciando\
# Plote ACF de séries estacionárias para ordem MA, ordem MA sazonal em picos sazonais\
# Traçar PACF de séries estacionárias para ordem AR, ordem AR sazonal em picos sazonais\
# Execute SARIMA com esses parâmetros\
# Verifique a validade do modelo usando gráficos de resíduos

# %%
from datetime import datetime

t1 = datetime.now()
t1
# Out:
# datetime.datetime(2022, 4, 29, 21, 23, 41, 730006)

# %%
from constantes import *

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from joblib import Parallel # Processamento paralelo
from multiprocessing import cpu_count
from joblib import delayed

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
from statsmodels.tsa.stattools import kpss
def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
      kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# #### Carregando os dados pré-processados para o modelo

# %%
filepath = "..\data\processed\CATEG_3.csv"
df = pd.read_csv(filepath).sort_values(by = ["DATE"])
df.head(3)
# Out:
#            DATE  UNITS_SOLD
# 627  2018-09-24           0
# 735  2018-09-25           0
# 623  2018-09-27           0

# %%
df = df[df["DATE"] > "2018-10-16"]
df['DATE'] = pd.to_datetime(df['DATE'])
df['UNITS_SOLD'] = df['UNITS_SOLD'].astype(float)
df.head(3)
# Out:
#           DATE  UNITS_SOLD
# 0   2018-10-18         1.0
# 71  2018-10-19         0.0
# 396 2018-10-20         1.0

# %%
df.isnull().sum()
df = df.dropna()
df.isnull().sum()
# Out:
# DATE          0
# UNITS_SOLD    0
# dtype: int64

# %%
df = df.set_index('DATE')

# %% [markdown]
# #### Será definida uma reamostragem com medias semanais para a análise. Pois será mais expressiva a métrica de sazonalidade a seguir.

# %%
# reamostragem pela média semanal
ts_month_avg = df['UNITS_SOLD'].resample(f'{LAPSO_MEAN_3}D').mean()
ts_month_avg = ts_month_avg.dropna()
ts_month_avg = ts_month_avg.asfreq(f'{LAPSO_MEAN_3}D', method='ffill') # Incluindo uma configuração de frequência

# %%
L = len(ts_month_avg)
train_df = ts_month_avg[0:int(L*TRAINNG_DATA_PERCENTAGE_3)]
test_df = ts_month_avg[int(L*TRAINNG_DATA_PERCENTAGE_3):int(L*(TRAINNG_DATA_PERCENTAGE_3 + TEST_DATA_PERCENTAGE_3))]
validation_df = ts_month_avg[int(L*(TRAINNG_DATA_PERCENTAGE_3 + TEST_DATA_PERCENTAGE_3)):]

# %% [markdown]
# __Gráfico dos dados__

# %%
train_df.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# __Identificando Variação, Tendência e Sazonalidade nos dados__\
# Vamos verificar a tendência e os componentes sazonais dos dados. Cada série temporal pode ser decomposta em 3 componentes
#
# Tendência\
# Sazonalidade\
# Ruído
#
# Vamos ver nossa série temporal decomposta –

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 18
decomposition = sm.tsa.seasonal_decompose(train_df, model='additive',period=12, extrapolate_trend = 12)
fig = decomposition.plot()
plt.show()

# %% [markdown]
# Como podemos ver, há uma tendência de alta e uma sazonalidade semestral (6 x 4 semans por mês implica um lag = 24) nos dados. Portanto, a série não é estacionária. Temos que lidar com a sazonalidade analisar o efeito. Será realizada a diferenciação e será verificado o resultado por testes estatísticos como ADF (para tendência) e OSCB (para sazonalidade).
#
# Regra de polegar para testes estatísticos -
# ADF(para tendência): se o valor p for menor que o valor crítico, a série é estacionária
# OSCB(para sazonalidade): se o valor for menor que 0,64, a série é estacionária

# %%
LAGS = int(SAZONALITY_MONTHS_3*(30/LAPSO_MEAN_3))
LAGS = int(LAGS*LAG_REDUCTION_FACTOR_3)
LAGS
# Out:
# 9

# %%
print(adf_test(train_df))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.166859
# p-value                         0.687687
# #Lags Used                      5.000000
# Number of Observations Used    84.000000
# Critical Value (1%)            -3.510712
# Critical Value (5%)            -2.896616
# Critical Value (10%)           -2.585482
# dtype: float64
# None

# %% [markdown]
# Depois de executar o teste ADF na série temporal, obtemos  __p__ = __0.112672__ que é maior que o valor crítico de 0,05. Assim podemos confirmar estatisticamente que a série não é estacionária. Portanto, podemos realizar uma diferenciação de primeira ordem para a tendência e executamos novamente o teste ADF para verificar a estacionariedade.

# %%
rcParams['figure.figsize'] = 18, 8
ts_t_adj = train_df - train_df.shift(1)
ts_t_adj = ts_t_adj.dropna()
ts_t_adj.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#apply adf test on the series
print(adf_test(ts_t_adj))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.834072
# p-value                         0.000047
# #Lags Used                      4.000000
# Number of Observations Used    84.000000
# Critical Value (1%)            -3.510712
# Critical Value (5%)            -2.896616
# Critical Value (10%)           -2.585482
# dtype: float64
# None

# %% [markdown]
# Observando o __p-value__ a __tendência__ agora parece ter desaparecido. O valor p é menor que o valor crítico de 0,05. Portanto, podemos confirmar que a série agora é uma tendência estacionária.

# %% [markdown]
# Passemos agora para a diferenciação __sazonal__. Como os dados estão mostrando uma sazonalidade semestral, realizaremos uma diferenciação com defasagem 15 dias => 12 lags.

# %%
ts_s_adj = ts_t_adj - ts_t_adj.shift(LAGS)
ts_s_adj = ts_s_adj.dropna()
ts_s_adj.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# Agora que os dados estão estacionários, vamos para a próxima etapa do processo – os gráficos ACF e PACF.
#
# Parcelas ACF e PACF
#
# Vamos tentar descobrir os parâmetos do modelo
#
# Para descobrir isso , precisaríamos traçar os gráficos ACF e PACF.
#
# ACF significa Função de Correlação Automática e PACF significa Função de Correlação Automática Parcial.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_s_adj)
matplotlib.pyplot.show()
plot_pacf(ts_s_adj)
matplotlib.pyplot.show()

# %% [markdown]
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
#
# Os parâmetros para esses tipos de modelos são os seguintes:
#
# __p__ e sazonal __P__: indicam o número de termos AR (defasagens da série estacionária)\
# __d__ e sazonal __D__: indicam diferenciações que devem ser feitas para as séries tornarem-se estacionárias\
# __q__ e __Q__ sazonal: indicam o número de termos MA (lags dos erros da previsão)\
# __lag__: indica o intervalo da sazonalidade nos dados
#
# __Estimando termos de AR, ou p__
#
# O gráfico de pirulito que você vê acima são os resultados do ACF e do PACF. Para estimar a quantidade de termos AR, você precisa olhar para o gráfico PACF. Primeiro, ignore o valor na defasagem 0. Ele sempre mostrará uma correlação perfeita, pois estamos estimando a correlação entre o valor de hoje consigo mesmo. Observe que há uma área azul no gráfico, representando o intervalo de confiança. Para estimar quantos termos de AR você deve usar, comece a contar quantos “pirulito” estão acima ou abaixo do intervalo de confiança antes que o próximo entre na área azul.
#
# p = 1
#
#
# __Estimativa de termos I, ou d__
#
# Esta é uma parte fácil. Tudo o que você precisa fazer para estimar a quantidade de I(d) termos é saber quantas diferenciações foram usadas para tornar a série estacionária. Por exemplo, se você usou diferença logarítmica ou primeira diferença para transformar uma série temporal, a quantidade de termos I será 1, pois Arauto toma a diferença entre o valor real (por exemplo, o valor de hoje) e 1 valor anterior (por exemplo, o valor de ontem).
#
# d = 1
#
# __Estimando termos de MA, ou q__
#
# Assim como a função PACF, para estimar a quantidade de termos MA, desta vez você observará o gráfico ACF. A mesma lógica é aplicada aqui: quantos pirulitos estão acima ou abaixo do intervalo de confiança antes que o próximo pirulito entre na área azul?
#
# q = 1
#
# __Estimando termos sazonais de RA, ou P__
# Caso seus dados possuam sazonalidade e você queira utilizar um modelo Sazonal ARIMA, é necessário informar os termos sazonais para AR, I e MA. O processo é bastante semelhante ao AR não sazonal, e você ainda usará a função ACF e PACF para isso. Para estimar a quantidade de termos AR, você examinará mais uma vez a função PACF. Agora, em vez de contar quantos pirulitos estão fora do intervalo de confiança, você contará quantos pirulitos sazonais estão fora.
#
# Como os dados possuem sazonalidade semestral, é preciso verificar se o “pirulito” na defasagem 6 está fora da área do intervalo de confiança. Em caso de resultado positivo, é necessário adicionar 1 termo para AR Sazonal. Como temos um pirulito negativo na posição 6 adicionamos 1.
#
# P = 0
#
# __Estimating Seasonal I terms__
#
# A mesma lógica de estimar a diferenciação não sazonal é aplicada aqui. Se você usou a diferenciação sazonal para tornar a série temporal estacionária (por exemplo, o valor real (Yt) subtraído por 12 meses anteriores (Yt-12)), você adicionará 1 termo à diferenciação sazonal.
#
# D = 1
#
# __Estimating Seasonal MA terms__
#
# Para a média móvel sazonal (SMA), estaremos olhando para o gráfico ACF e usaremos a mesma lógica de estimar os termos SAR.
# Como só temos uma correlação forte em 4 temos, estimamos que o valor deve ser 0 ou 1.
#
# Q = 0
#
# lag = 18
#
# Portanto,
#
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
# $SARIMA(0,1,0)\times(1,1,1)_{26}$

# %% [markdown]
# ### A seguir são realizadas algumas combinações de parâmetros para serem restados nas tentavas de otimizações a seguir utilizando a métrica AIC para a avaliação do modelo treinado.

# %%
p = range(0, 3)
d = range(0, 2)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = []
for x in list(itertools.product(p, d, q)):
    seasonal_pdq.append((x[0], x[1], x[2], LAGS) )

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
TOTAL_TEST = len(pdq)*len(seasonal_pdq)
print(f"Serão realizado {TOTAL_TEST} testes no total.")
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 9)
# SARIMAX: (0, 0, 1) x (0, 0, 2, 9)
# SARIMAX: (0, 0, 2) x (0, 1, 0, 9)
# Serão realizado 324 testes no total.

# %% [markdown]
# ### A seguir é construído um script que testa combinações dos parâmetros e mede a métrica AIC para verificar qual a melhor combinação testada.

# %%
from operator import itemgetter
params_list = []
params_list_top = []
cont = 0
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_df,
                                            order= param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            # param = (1, 1, 1)
            cont +=1
            print(f"Teste {cont}/{TOTAL_TEST}")
            print('ARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            params_list.append([param, param_seasonal, results.aic])
            params_list_sort = []
            params_list_sort = sorted(params_list, key=itemgetter(2))
            params_list_sort_1 = params_list_sort[0]
            params_list_sort_2 = params_list_sort[2]
            params_list_sort_3 = params_list_sort[3]
            params_list_sort_4 = params_list_sort[4]
            params_list_sort_5 = params_list_sort[5]
            print(f'TOP 1 SARIMA params: {params_list_sort_1[0]}x{params_list_sort_1[1]} - AIC:{params_list_sort_1[2]}')
            print(f'TOP 2 SARIMA params: {params_list_sort_2[0]}x{params_list_sort_2[1]} - AIC:{params_list_sort_2[2]}')
            print(f'TOP 3 SARIMA params: {params_list_sort_3[0]}x{params_list_sort_3[1]} - AIC:{params_list_sort_3[2]}')
            print(f'TOP 4 SARIMA params: {params_list_sort_4[0]}x{params_list_sort_4[1]} - AIC:{params_list_sort_4[2]}')
            print(f'TOP 5 SARIMA params: {params_list_sort_5[0]}x{params_list_sort_5[1]} - AIC:{params_list_sort_5[2]}')
        except:
            continue

params_list_sort = []
params_list_sort = sorted(params_list, key=itemgetter(2))[0]
print(f'Best SARIMA params: {params_list_sort[0]}x{params_list_sort[1]} - AIC:{params_list_sort[2]}')
# Out:
# Optimization terminated successfully.
#          Current function value: 8.567208
#          Iterations: 1
#          Function evaluations: 18
# Teste 1/324
# ARIMA(0, 0, 0)x(0, 0, 0, 9) - AIC:1544.09737134268
# Optimization terminated successfully.
#          Current function value: 8.273710
#          Iterations: 3
#          Function evaluations: 80
# Teste 2/324
# ARIMA(0, 0, 0)x(0, 0, 1, 9) - AIC:1493.2678785114545
# Optimization terminated successfully.
#          Current function value: 8.045736
#          Iterations: 5
#          Function evaluations: 194
# Teste 3/324
# ARIMA(0, 0, 0)x(0, 0, 2, 9) - AIC:1454.2325431012428
# Optimization terminated successfully.
#          Current function value: 7.079975
#          Iterations: 2
#          Function evaluations: 38
# Teste 4/324
# ARIMA(0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# Optimization terminated successfully.
#          Current function value: 7.036644
#          Iterations: 2
#          Function evaluations: 44
# Teste 5/324
# ARIMA(0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# Optimization terminated successfully.
#          Current function value: 6.945567
#          Iterations: 3
#          Function evaluations: 116
# Teste 6/324
# ARIMA(0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# TOP 3 SARIMA params: (0, 0, 0)x(0, 0, 2, 9) - AIC:1454.2325431012428
# TOP 4 SARIMA params: (0, 0, 0)x(0, 0, 1, 9) - AIC:1493.2678785114545
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 0, 9) - AIC:1544.09737134268
# Optimization terminated successfully.
#          Current function value: 7.918656
#          Iterations: 2
#          Function evaluations: 58
# Teste 7/324
# ARIMA(0, 0, 0)x(1, 0, 0, 9) - AIC:1429.3581686363755
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# TOP 3 SARIMA params: (0, 0, 0)x(1, 0, 0, 9) - AIC:1429.3581686363755
# TOP 4 SARIMA params: (0, 0, 0)x(0, 0, 2, 9) - AIC:1454.2325431012428
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 1, 9) - AIC:1493.2678785114545
# Optimization terminated successfully.
#          Current function value: 7.891855
#          Iterations: 5
#          Function evaluations: 195
# Teste 8/324
# ARIMA(0, 0, 0)x(1, 0, 1, 9) - AIC:1426.5339023894678
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# TOP 3 SARIMA params: (0, 0, 0)x(1, 0, 1, 9) - AIC:1426.5339023894678
# TOP 4 SARIMA params: (0, 0, 0)x(1, 0, 0, 9) - AIC:1429.3581686363755
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 2, 9) - AIC:1454.2325431012428
# Optimization terminated successfully.
#          Current function value: 7.805127
#          Iterations: 9
#          Function evaluations: 442
# Teste 9/324
# ARIMA(0, 0, 0)x(1, 0, 2, 9) - AIC:1412.9229325779513
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# TOP 3 SARIMA params: (0, 0, 0)x(1, 0, 2, 9) - AIC:1412.9229325779513
# TOP 4 SARIMA params: (0, 0, 0)x(1, 0, 1, 9) - AIC:1426.5339023894678
# TOP 5 SARIMA params: (0, 0, 0)x(1, 0, 0, 9) - AIC:1429.3581686363755
# Optimization terminated successfully.
#          Current function value: 6.998848
#          Iterations: 2
#          Function evaluations: 47
# Teste 10/324
# ARIMA(0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# TOP 4 SARIMA params: (0, 0, 0)x(1, 0, 2, 9) - AIC:1412.9229325779513
# TOP 5 SARIMA params: (0, 0, 0)x(1, 0, 1, 9) - AIC:1426.5339023894678
# Optimization terminated successfully.
#          Current function value: 6.945634
#          Iterations: 4
#          Function evaluations: 145
# Teste 11/324
# ARIMA(0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# TOP 5 SARIMA params: (0, 0, 0)x(1, 0, 2, 9) - AIC:1412.9229325779513
# Optimization terminated successfully.
#          Current function value: 6.908311
#          Iterations: 5
#          Function evaluations: 249
# Teste 12/324
# ARIMA(0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 1 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# Optimization terminated successfully.
#          Current function value: 7.863988
#          Iterations: 2
#          Function evaluations: 85
# Teste 13/324
# ARIMA(0, 0, 0)x(2, 0, 0, 9) - AIC:1421.517786957717
# TOP 1 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# Optimization terminated successfully.
#          Current function value: 7.814742
#          Iterations: 7
#          Function evaluations: 356
# Teste 14/324
# ARIMA(0, 0, 0)x(2, 0, 1, 9) - AIC:1414.6536321089395
# TOP 1 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# Optimization terminated successfully.
#          Current function value: 7.774866
#          Iterations: 5
#          Function evaluations: 312
# Teste 15/324
# ARIMA(0, 0, 0)x(2, 0, 2, 9) - AIC:1409.4759288847195
# TOP 1 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 9) - AIC:1276.3954581926262
# Optimization terminated successfully.
#          Current function value: 6.890614
#          Iterations: 3
#          Function evaluations: 112
# Teste 16/324
# ARIMA(0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 1, 9) - AIC:1270.5959802152142
# Optimization terminated successfully.
#          Current function value: 6.845722
#          Iterations: 8
#          Function evaluations: 384
# Teste 17/324
# ARIMA(0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 0, 9) - AIC:1263.7926359922799
# Optimization terminated successfully.
#          Current function value: 6.844748
#          Iterations: 7
#          Function evaluations: 423
# Teste 18/324
# ARIMA(0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 2 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# Optimization terminated successfully.
#          Current function value: 8.004322
#          Iterations: 2
#          Function evaluations: 53
# Teste 19/324
# ARIMA(0, 0, 1)x(0, 0, 0, 9) - AIC:1444.7780031509128
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 2 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# Optimization terminated successfully.
#          Current function value: 7.788863
#          Iterations: 4
#          Function evaluations: 145
# Teste 20/324
# ARIMA(0, 0, 1)x(0, 0, 1, 9) - AIC:1407.9953788445814
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 2 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# Optimization terminated successfully.
#          Current function value: 7.648820
#          Iterations: 5
#          Function evaluations: 251
# Teste 21/324
# ARIMA(0, 0, 1)x(0, 0, 2, 9) - AIC:1384.7876614227162
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 2 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 9) - AIC:1256.214174496315
# Optimization terminated successfully.
#          Current function value: 6.764980
#          Iterations: 2
#          Function evaluations: 45
# Teste 22/324
# ARIMA(0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 2 SARIMA params: (0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 2, 9) - AIC:1256.2020067724038
# Optimization terminated successfully.
#          Current function value: 6.706094
#          Iterations: 2
#          Function evaluations: 69
# Teste 23/324
# ARIMA(0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 2 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 2, 9) - AIC:1251.4959938548218
# Optimization terminated successfully.
#          Current function value: 6.657000
#          Iterations: 3
#          Function evaluations: 138
# Teste 24/324
# ARIMA(0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# Optimization terminated successfully.
#          Current function value: 7.541112
#          Iterations: 4
#          Function evaluations: 149
# Teste 25/324
# ARIMA(0, 0, 1)x(1, 0, 0, 9) - AIC:1363.4001959736177
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# Optimization terminated successfully.
#          Current function value: 7.506197
#          Iterations: 5
#          Function evaluations: 246
# Teste 26/324
# ARIMA(0, 0, 1)x(1, 0, 1, 9) - AIC:1359.1155271290213
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# Optimization terminated successfully.
#          Current function value: 7.462339
#          Iterations: 6
#          Function evaluations: 364
# Teste 27/324
# ARIMA(0, 0, 1)x(1, 0, 2, 9) - AIC:1353.221070875548
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 0, 9) - AIC:1246.310532261374
# Optimization terminated successfully.
#          Current function value: 6.674406
#          Iterations: 2
#          Function evaluations: 72
# Teste 28/324
# ARIMA(0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 3 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 2, 9) - AIC:1242.054635939625
# Optimization terminated successfully.
#          Current function value: 6.659580
#          Iterations: 4
#          Function evaluations: 194
# Teste 29/324
# ARIMA(0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# TOP 3 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 1, 9) - AIC:1240.2300437283916
# Optimization terminated successfully.
#          Current function value: 6.650177
#          Iterations: 7
#          Function evaluations: 417
# Teste 30/324
# ARIMA(0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# Optimization terminated successfully.
#          Current function value: 7.482905
#          Iterations: 4
#          Function evaluations: 208
# Teste 31/324
# ARIMA(0, 0, 1)x(2, 0, 0, 9) - AIC:1354.9229575968618
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# Optimization terminated successfully.
#          Current function value: 7.470438
#          Iterations: 6
#          Function evaluations: 375
# Teste 32/324
# ARIMA(0, 0, 1)x(2, 0, 1, 9) - AIC:1354.6788844685148
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# Optimization terminated successfully.
#          Current function value: 7.457973
#          Iterations: 5
#          Function evaluations: 370
# Teste 33/324
# ARIMA(0, 0, 1)x(2, 0, 2, 9) - AIC:1354.435180374016
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 9) - AIC:1221.6963494495453
# Optimization terminated successfully.
#          Current function value: 6.648998
#          Iterations: 3
#          Function evaluations: 137
# Teste 34/324
# ARIMA(0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 1, 9) - AIC:1213.0970025379195
# Optimization terminated successfully.
#          Current function value: 6.616061
#          Iterations: 11
#          Function evaluations: 643
# Teste 35/324
# ARIMA(0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# Optimization terminated successfully.
#          Current function value: 6.644574
#          Iterations: 5
#          Function evaluations: 343
# Teste 36/324
# ARIMA(0, 0, 1)x(2, 1, 2, 9) - AIC:1208.0233906465062
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# Optimization terminated successfully.
#          Current function value: 7.627350
#          Iterations: 3
#          Function evaluations: 124
# Teste 37/324
# ARIMA(0, 0, 2)x(0, 0, 0, 9) - AIC:1378.9229756195934
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# Optimization terminated successfully.
#          Current function value: 7.481411
#          Iterations: 4
#          Function evaluations: 214
# Teste 38/324
# ARIMA(0, 0, 2)x(0, 0, 1, 9) - AIC:1354.6540344638981
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# Optimization terminated successfully.
#          Current function value: 7.416129
#          Iterations: 5
#          Function evaluations: 299
# Teste 39/324
# ARIMA(0, 0, 2)x(0, 0, 2, 9) - AIC:1344.9031501247866
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 9) - AIC:1207.3930678756178
# Optimization terminated successfully.
#          Current function value: 6.642824
#          Iterations: 3
#          Function evaluations: 112
# Teste 40/324
# ARIMA(0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 2 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 3 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 2, 9) - AIC:1207.0319222722846
# Optimization terminated successfully.
#          Current function value: 6.571684
#          Iterations: 3
#          Function evaluations: 140
# Teste 41/324
# ARIMA(0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 1, 9) - AIC:1206.7244680204897
# Optimization terminated successfully.
#          Current function value: 6.557104
#          Iterations: 3
#          Function evaluations: 172
# Teste 42/324
# ARIMA(0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 2 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# Optimization terminated successfully.
#          Current function value: 7.361286
#          Iterations: 4
#          Function evaluations: 215
# Teste 43/324
# ARIMA(0, 0, 2)x(1, 0, 0, 9) - AIC:1333.0315591495757
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 2 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# Optimization terminated successfully.
#          Current function value: 7.330434
#          Iterations: 5
#          Function evaluations: 302
# Teste 44/324
# ARIMA(0, 0, 2)x(1, 0, 1, 9) - AIC:1329.478190444234
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 2 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# Optimization terminated successfully.
#          Current function value: 7.322475
#          Iterations: 7
#          Function evaluations: 493
# Teste 45/324
# ARIMA(0, 0, 2)x(1, 0, 2, 9) - AIC:1330.0454417462329
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 2 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 2, 9) - AIC:1206.2599371297713
# Optimization terminated successfully.
#          Current function value: 6.557050
#          Iterations: 3
#          Function evaluations: 144
# Teste 46/324
# ARIMA(0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 0, 9) - AIC:1204.8195520351692
# Optimization terminated successfully.
#          Current function value: 6.556192
#          Iterations: 3
#          Function evaluations: 174
# Teste 47/324
# ARIMA(0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# TOP 5 SARIMA params: (0, 0, 2)x(0, 1, 0, 9) - AIC:1201.708342493234
# Optimization terminated successfully.
#          Current function value: 6.562704
#          Iterations: 3
#          Function evaluations: 209
# Teste 48/324
# ARIMA(0, 0, 2)x(1, 1, 2, 9) - AIC:1193.286668065198
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 9) - AIC:1193.286668065198
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# Optimization terminated successfully.
#          Current function value: 7.322802
#          Iterations: 4
#          Function evaluations: 265
# Teste 49/324
# ARIMA(0, 0, 2)x(2, 0, 0, 9) - AIC:1328.1043848025874
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 9) - AIC:1193.286668065198
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# Optimization terminated successfully.
#          Current function value: 7.323844
#          Iterations: 4
#          Function evaluations: 309
# Teste 50/324
# ARIMA(0, 0, 2)x(2, 0, 1, 9) - AIC:1330.2919520210921
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 9) - AIC:1193.286668065198
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# Optimization terminated successfully.
#          Current function value: 7.322052
#          Iterations: 5
#          Function evaluations: 425
# Teste 51/324
# ARIMA(0, 0, 2)x(2, 0, 2, 9) - AIC:1331.9693992683558
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 9) - AIC:1193.286668065198
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 9) - AIC:1200.8910172287153
# Optimization terminated successfully.
#          Current function value: 6.556070
#          Iterations: 3
#          Function evaluations: 177
# Teste 52/324
# ARIMA(0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 2, 9) - AIC:1193.286668065198
# Optimization terminated successfully.
#          Current function value: 6.555175
#          Iterations: 3
#          Function evaluations: 205
# Teste 53/324
# ARIMA(0, 0, 2)x(2, 1, 1, 9) - AIC:1191.9315785271438
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 9) - AIC:1191.9315785271438
# Optimization terminated successfully.
#          Current function value: 6.555987
#          Iterations: 3
#          Function evaluations: 246
# Teste 54/324
# ARIMA(0, 0, 2)x(2, 1, 2, 9) - AIC:1194.0777470678142
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 9) - AIC:1191.9315785271438
# Optimization terminated successfully.
#          Current function value: 6.873476
#          Iterations: 1
#          Function evaluations: 10
# Teste 55/324
# ARIMA(0, 1, 0)x(0, 0, 0, 9) - AIC:1239.2257479252419
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 9) - AIC:1191.9315785271438
# Optimization terminated successfully.
#          Current function value: 6.873286
#          Iterations: 2
#          Function evaluations: 44
# Teste 56/324
# ARIMA(0, 1, 0)x(0, 0, 1, 9) - AIC:1241.1914675971627
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 9) - AIC:1191.9315785271438
# Optimization terminated successfully.
#          Current function value: 6.873286
#          Iterations: 2
#          Function evaluations: 67
# Teste 57/324
# ARIMA(0, 1, 0)x(0, 0, 2, 9) - AIC:1243.191409700718
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 9) - AIC:1191.9315785271438
# Optimization terminated successfully.
#          Current function value: 6.531878
#          Iterations: 2
#          Function evaluations: 37
# Teste 58/324
# ARIMA(0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 2 SARIMA params: (0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# TOP 5 SARIMA params: (0, 0, 2)x(0, 1, 1, 9) - AIC:1190.9030752211445
# Optimization terminated successfully.
#          Current function value: 6.301436
#          Iterations: 3
#          Function evaluations: 77
# Teste 59/324
# ARIMA(0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# TOP 5 SARIMA params: (0, 0, 2)x(0, 1, 2, 9) - AIC:1190.278658866676
# Optimization terminated successfully.
#          Current function value: 6.301145
#          Iterations: 3
#          Function evaluations: 117
# Teste 60/324
# ARIMA(0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 4 SARIMA params: (0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# Optimization terminated successfully.
#          Current function value: 6.873286
#          Iterations: 2
#          Function evaluations: 44
# Teste 61/324
# ARIMA(0, 1, 0)x(1, 0, 0, 9) - AIC:1241.1914392779397
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 4 SARIMA params: (0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# Optimization terminated successfully.
#          Current function value: 6.873263
#          Iterations: 2
#          Function evaluations: 68
# Teste 62/324
# ARIMA(0, 1, 0)x(1, 0, 1, 9) - AIC:1243.1872627612238
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 4 SARIMA params: (0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# Optimization terminated successfully.
#          Current function value: 6.872919
#          Iterations: 3
#          Function evaluations: 145
# Teste 63/324
# ARIMA(0, 1, 0)x(1, 0, 2, 9) - AIC:1245.1254967332459
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 4 SARIMA params: (0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 1, 9) - AIC:1190.1145468912687
# Optimization terminated successfully.
#          Current function value: 6.376275
#          Iterations: 2
#          Function evaluations: 47
# Teste 64/324
# ARIMA(0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# TOP 3 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 0, 9) - AIC:1190.0926189399556
# Optimization terminated successfully.
#          Current function value: 6.303084
#          Iterations: 4
#          Function evaluations: 150
# Teste 65/324
# ARIMA(0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 0, 9) - AIC:1188.2690505830742
# Optimization terminated successfully.
#          Current function value: 6.300192
#          Iterations: 4
#          Function evaluations: 205
# Teste 66/324
# ARIMA(0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# Optimization terminated successfully.
#          Current function value: 6.873284
#          Iterations: 2
#          Function evaluations: 67
# Teste 67/324
# ARIMA(0, 1, 0)x(2, 0, 0, 9) - AIC:1243.1911275392947
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# Optimization terminated successfully.
#          Current function value: 6.873212
#          Iterations: 2
#          Function evaluations: 89
# Teste 68/324
# ARIMA(0, 1, 0)x(2, 0, 1, 9) - AIC:1245.178147300051
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# Optimization terminated successfully.
#          Current function value: 6.873275
#          Iterations: 2
#          Function evaluations: 107
# Teste 69/324
# ARIMA(0, 1, 0)x(2, 0, 2, 9) - AIC:1247.1894511576227
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 0, 9) - AIC:1177.7381039029244
# Optimization terminated successfully.
#          Current function value: 6.351099
#          Iterations: 2
#          Function evaluations: 71
# Teste 70/324
# ARIMA(0, 1, 0)x(2, 1, 0, 9) - AIC:1149.1978428315706
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 0, 9) - AIC:1149.1978428315706
# TOP 5 SARIMA params: (0, 1, 0)x(1, 1, 0, 9) - AIC:1151.7294741178812
# Optimization terminated successfully.
#          Current function value: 6.301626
#          Iterations: 7
#          Function evaluations: 342
# Teste 71/324
# ARIMA(0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 0, 9) - AIC:1149.1978428315706
# Optimization terminated successfully.
#          Current function value: 6.300654
#          Iterations: 5
#          Function evaluations: 304
# Teste 72/324
# ARIMA(0, 1, 0)x(2, 1, 2, 9) - AIC:1144.1176473364621
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 9) - AIC:1144.1176473364621
# Optimization terminated successfully.
#          Current function value: 6.869288
#          Iterations: 2
#          Function evaluations: 46
# Teste 73/324
# ARIMA(0, 1, 1)x(0, 0, 0, 9) - AIC:1240.4718093727913
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 9) - AIC:1144.1176473364621
# Optimization terminated successfully.
#          Current function value: 6.868967
#          Iterations: 2
#          Function evaluations: 67
# Teste 74/324
# ARIMA(0, 1, 1)x(0, 0, 1, 9) - AIC:1242.414060314206
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 9) - AIC:1144.1176473364621
# Optimization terminated successfully.
#          Current function value: 6.868477
#          Iterations: 3
#          Function evaluations: 141
# Teste 75/324
# ARIMA(0, 1, 1)x(0, 0, 2, 9) - AIC:1244.32583332154
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 9) - AIC:1144.1176473364621
# Optimization terminated successfully.
#          Current function value: 6.528747
#          Iterations: 2
#          Function evaluations: 47
# Teste 76/324
# ARIMA(0, 1, 1)x(0, 1, 0, 9) - AIC:1179.1744370988813
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 9) - AIC:1144.1176473364621
# Optimization terminated successfully.
#          Current function value: 6.294199
#          Iterations: 3
#          Function evaluations: 111
# Teste 77/324
# ARIMA(0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 1, 9) - AIC:1142.2926858956826
# Optimization terminated successfully.
#          Current function value: 6.293036
#          Iterations: 3
#          Function evaluations: 146
# Teste 78/324
# ARIMA(0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# Optimization terminated successfully.
#          Current function value: 6.868951
#          Iterations: 2
#          Function evaluations: 68
# Teste 79/324
# ARIMA(0, 1, 1)x(1, 0, 0, 9) - AIC:1242.4111882776851
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# Optimization terminated successfully.
#          Current function value: 6.868819
#          Iterations: 2
#          Function evaluations: 90
# Teste 80/324
# ARIMA(0, 1, 1)x(1, 0, 1, 9) - AIC:1244.3874943377598
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# Optimization terminated successfully.
#          Current function value: 6.866622
#          Iterations: 4
#          Function evaluations: 248
# Teste 81/324
# ARIMA(0, 1, 1)x(1, 0, 2, 9) - AIC:1245.991968645772
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# Optimization terminated successfully.
#          Current function value: 6.357860
#          Iterations: 3
#          Function evaluations: 101
# Teste 82/324
# ARIMA(0, 1, 1)x(1, 1, 0, 9) - AIC:1150.4147543415415
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 0)x(1, 1, 2, 9) - AIC:1142.0345510102168
# Optimization terminated successfully.
#          Current function value: 6.293641
#          Iterations: 4
#          Function evaluations: 200
# Teste 83/324
# ARIMA(0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.289716
#          Iterations: 4
#          Function evaluations: 245
# Teste 84/324
# ARIMA(0, 1, 1)x(1, 1, 2, 9) - AIC:1142.1488739938745
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.868311
#          Iterations: 2
#          Function evaluations: 88
# Teste 85/324
# ARIMA(0, 1, 1)x(2, 0, 0, 9) - AIC:1244.2960195798753
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.867817
#          Iterations: 2
#          Function evaluations: 110
# Teste 86/324
# ARIMA(0, 1, 1)x(2, 0, 1, 9) - AIC:1246.2071456780563
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.868038
#          Iterations: 3
#          Function evaluations: 207
# Teste 87/324
# ARIMA(0, 1, 1)x(2, 0, 2, 9) - AIC:1248.2467862510744
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.340485
#          Iterations: 3
#          Function evaluations: 140
# Teste 88/324
# ARIMA(0, 1, 1)x(2, 1, 0, 9) - AIC:1149.2872942095298
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.292230
#          Iterations: 8
#          Function evaluations: 465
# Teste 89/324
# ARIMA(0, 1, 1)x(2, 1, 1, 9) - AIC:1142.6013658877469
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.289826
#          Iterations: 5
#          Function evaluations: 350
# Teste 90/324
# ARIMA(0, 1, 1)x(2, 1, 2, 9) - AIC:1144.168610606487
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 2, 9) - AIC:1140.7464864200492
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 9) - AIC:1140.855377167472
# Optimization terminated successfully.
#          Current function value: 6.855199
#          Iterations: 2
#          Function evaluations: 65
# Teste 91/324
# ARIMA(0, 1, 2)x(0, 0, 0, 9) - AIC:1239.9357438565207
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 9) - AIC:1140.2061415878834
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 9) - AIC:1140.5550631252058
# ...
# Optimization terminated successfully.
#          Current function value: 6.841137
#          Iterations: 3
#          Function evaluations: 213
# Teste 296/324
# ARIMA(2, 1, 1)x(1, 0, 1, 9) - AIC:1243.40466976755
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.839018
#          Iterations: 5
#          Function evaluations: 409
# Teste 297/324
# ARIMA(2, 1, 1)x(1, 0, 2, 9) - AIC:1245.0232498750702
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.337551
#          Iterations: 2
#          Function evaluations: 117
# Teste 298/324
# ARIMA(2, 1, 1)x(1, 1, 0, 9) - AIC:1150.7591743093978
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.268774
#          Iterations: 6
#          Function evaluations: 433
# Teste 299/324
# ARIMA(2, 1, 1)x(1, 1, 1, 9) - AIC:1140.3793077284772
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.263938
#          Iterations: 5
#          Function evaluations: 416
# Teste 300/324
# ARIMA(2, 1, 1)x(1, 1, 2, 9) - AIC:1141.5087786093088
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.840389
#          Iterations: 4
#          Function evaluations: 273
# Teste 301/324
# ARIMA(2, 1, 1)x(2, 0, 0, 9) - AIC:1243.2700488217515
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.839344
#          Iterations: 4
#          Function evaluations: 318
# Teste 302/324
# ARIMA(2, 1, 1)x(2, 0, 1, 9) - AIC:1245.0819490489491
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.839608
#          Iterations: 6
#          Function evaluations: 531
# Teste 303/324
# ARIMA(2, 1, 1)x(2, 0, 2, 9) - AIC:1247.1294095904975
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.323152
#          Iterations: 4
#          Function evaluations: 274
# Teste 304/324
# ARIMA(2, 1, 1)x(2, 1, 0, 9) - AIC:1150.1673112898309
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.266311
#          Iterations: 10
#          Function evaluations: 820
# Teste 305/324
# ARIMA(2, 1, 1)x(2, 1, 1, 9) - AIC:1141.93590607419
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.262110
#          Iterations: 7
#          Function evaluations: 649
# Teste 306/324
# ARIMA(2, 1, 1)x(2, 1, 2, 9) - AIC:1143.1798047901486
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.815396
#          Iterations: 6
#          Function evaluations: 352
# Teste 307/324
# ARIMA(2, 1, 2)x(0, 0, 0, 9) - AIC:1236.7712824121352
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.815486
#          Iterations: 6
#          Function evaluations: 416
# Teste 308/324
# ARIMA(2, 1, 2)x(0, 0, 1, 9) - AIC:1238.78745696524
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.811583
#          Iterations: 9
#          Function evaluations: 707
# Teste 309/324
# ARIMA(2, 1, 2)x(0, 0, 2, 9) - AIC:1240.0848586453328
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.409853
#          Iterations: 9
#          Function evaluations: 537
# Teste 310/324
# ARIMA(2, 1, 2)x(0, 1, 0, 9) - AIC:1163.7735050022552
# TOP 1 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 3 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 4 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# TOP 5 SARIMA params: (2, 1, 0)x(0, 1, 2, 9) - AIC:1139.3366568413112
# Optimization terminated successfully.
#          Current function value: 6.245083
#          Iterations: 6
#          Function evaluations: 412
# Teste 311/324
# ARIMA(2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 3 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 4 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# TOP 5 SARIMA params: (0, 1, 2)x(0, 1, 1, 9) - AIC:1138.9650855559894
# Optimization terminated successfully.
#          Current function value: 6.241143
#          Iterations: 7
#          Function evaluations: 568
# Teste 312/324
# ARIMA(2, 1, 2)x(0, 1, 2, 9) - AIC:1137.4057824979632
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 5 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# Optimization terminated successfully.
#          Current function value: 6.815628
#          Iterations: 6
#          Function evaluations: 417
# Teste 313/324
# ARIMA(2, 1, 2)x(1, 0, 0, 9) - AIC:1238.8129569599478
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 5 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# Optimization terminated successfully.
#          Current function value: 6.815722
#          Iterations: 6
#          Function evaluations: 485
# Teste 314/324
# ARIMA(2, 1, 2)x(1, 0, 1, 9) - AIC:1240.8300325960383
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 5 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# Optimization terminated successfully.
#          Current function value: 6.808487
#          Iterations: 9
#          Function evaluations: 829
# Teste 315/324
# ARIMA(2, 1, 2)x(1, 0, 2, 9) - AIC:1241.52762889111
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 5 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# Optimization terminated successfully.
#          Current function value: 6.306505
#          Iterations: 10
#          Function evaluations: 688
# Teste 316/324
# ARIMA(2, 1, 2)x(1, 1, 0, 9) - AIC:1147.170938208837
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# TOP 5 SARIMA params: (0, 1, 1)x(0, 1, 1, 9) - AIC:1138.9558962963274
# Optimization terminated successfully.
#          Current function value: 6.245584
#          Iterations: 6
#          Function evaluations: 486
# Teste 317/324
# ARIMA(2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Optimization terminated successfully.
#          Current function value: 6.242287
#          Iterations: 7
#          Function evaluations: 717
# Teste 318/324
# ARIMA(2, 1, 2)x(1, 1, 2, 9) - AIC:1139.6115939517456
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Optimization terminated successfully.
#          Current function value: 6.816380
#          Iterations: 6
#          Function evaluations: 485
# Teste 319/324
# ARIMA(2, 1, 2)x(2, 0, 0, 9) - AIC:1240.9483514327085
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Optimization terminated successfully.
#          Current function value: 6.815437
#          Iterations: 6
#          Function evaluations: 551
# Teste 320/324
# ARIMA(2, 1, 2)x(2, 0, 1, 9) - AIC:1242.7786623624586
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Optimization terminated successfully.
#          Current function value: 6.809367
#          Iterations: 9
#          Function evaluations: 899
# Teste 321/324
# ARIMA(2, 1, 2)x(2, 0, 2, 9) - AIC:1243.6861206537785
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Optimization terminated successfully.
#          Current function value: 6.294554
#          Iterations: 9
#          Function evaluations: 736
# Teste 322/324
# ARIMA(2, 1, 2)x(2, 1, 0, 9) - AIC:1147.019649912358
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Optimization terminated successfully.
#          Current function value: 6.240541
#          Iterations: 11
#          Function evaluations: 1002
# Teste 323/324
# ARIMA(2, 1, 2)x(2, 1, 1, 9) - AIC:1139.297405500507
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Optimization terminated successfully.
#          Current function value: 6.238993
#          Iterations: 9
#          Function evaluations: 978
# Teste 324/324
# ARIMA(2, 1, 2)x(2, 1, 2, 9) - AIC:1141.0186925956632
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Best SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826

# %% [markdown]
# ````
# Teste 324/324
# ARIMA(2, 1, 2)x(2, 1, 2, 9) - AIC:1141.0186925956632
# TOP 1 SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# TOP 2 SARIMA params: (2, 1, 0)x(0, 1, 1, 9) - AIC:1137.4384692200874
# TOP 3 SARIMA params: (2, 1, 2)x(1, 1, 1, 9) - AIC:1138.2050855234133
# TOP 4 SARIMA params: (2, 1, 1)x(0, 1, 1, 9) - AIC:1138.2253689829472
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 9) - AIC:1138.258512441274
# Best SARIMA params: (2, 1, 2)x(0, 1, 1, 9) - AIC:1136.1149876069826
# ````

# %%
mod = sm.tsa.statespace.SARIMAX(train_df,
                                order=(0, 2, 0),
                                seasonal_order=(2, 1, 2, LAGS))
results = mod.fit(method = 'powell')
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 6.564077
#          Iterations: 6
#          Function evaluations: 378
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L9       -0.8470      0.910     -0.930      0.352      -2.631       0.937
# ar.S.L18      -0.0656      0.452     -0.145      0.885      -0.952       0.821
# ma.S.L9       -0.0538      1.484     -0.036      0.971      -2.961       2.854
# ma.S.L18      -0.8818      2.100     -0.420      0.675      -4.998       3.234
# sigma2      1.433e+05   2.06e+05      0.697      0.486    -2.6e+05    5.47e+05
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
START_TIME_PREDICTION = train_df.index.max()
START_TIME_PREDICTION
# Out:
# Timestamp('2021-03-26 00:00:00', freq='10D')

# %%
import datetime
END_TIME_PREDICTION = validation_df.index.max() + datetime.timedelta(days=+120)

# %%
pred = results.get_prediction(start=START_TIME_PREDICTION, dynamic=True, end=END_TIME_PREDICTION)
pred_ci = pred.conf_int(alpha=0.05)
ax = ts_month_avg.plot(label='Dados Originais', color = "blue")
ax = train_df.plot(label='Dados Treino', color = "green")
pred.predicted_mean.plot(ax=ax, label='Previsão', alpha=.7, figsize=(14, 4), color = "red")
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('DATE')
ax.set_ylabel('UNITS_SOLD')
plt.ylim([1000, 4000])

TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS = 6

TIME_INTERAVAL_TO_OBSERVE = TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS*7
 
plt.xlim([START_TIME_PREDICTION + datetime.timedelta(days=-TIME_INTERAVAL_TO_OBSERVE/8), START_TIME_PREDICTION + datetime.timedelta(days=TIME_INTERAVAL_TO_OBSERVE)])
plt.title(f"Previsão para {TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS} semanas.")
plt.legend()
plt.show()

# %%
from datetime import datetime
t2 = datetime.now()
dt = t2 - t1
print(f"O tempo total para rodar o sript foi de {dt}")
# Out:
# O tempo total para rodar o sript foi de 0:01:44.694566
