# %% [markdown]
# __Equação SARIMA__\
# Uma equação típica do modelo SARIMA se parece com o seguinte –
#
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
#
# Os parâmetros para esses tipos de modelos são os seguintes:
#
# __p__ e sazonal __P__: indicam o número de termos AR (defasagens da série estacionária)\
# __d__ e sazonal __D__: indicam diferenciações que devem ser feitas para as séries tornarem-se estacionárias\
# __q__ e __Q__ sazonal: indicam o número de termos MA (lags dos erros da previsão)\
# __lag__: indica o intervalo da sazonalidade nos dados

# %% [markdown]
# __Fazendo com que uma série temporal torne-se estacionária__
#
# Uma série temporal estacionária é aquela que não possui nenhuma tendência ou sazonalidade. É essencial lidar com qualquer tendência ou sazonalidade antes de modelar os dados da série temporal porque se as propriedades estatísticas não mudarem ao longo do tempo, torna-se mais fácil modelar os dados com precisão. Uma das maneiras populares de se fazer com que a série torne-se estacionária é __diferenciando__.

# %% [markdown]
# __Modelagem SARIMA__
#
#
# Plote a série - para verificar se há discrepâncias\
# Transforme os dados (para tornar a média e a variância constantes)\
# Aplique testes estatísticos para verificar se a série é estacionária (tanto de tendência quanto de sazonalidade)\
# Se não estacionário (ou seja, se possui tendência ou sazonalidade), torne-a estacionária diferenciando\
# Plote ACF de séries estacionárias para ordem MA, ordem MA sazonal em picos sazonais\
# Traçar PACF de séries estacionárias para ordem AR, ordem AR sazonal em picos sazonais\
# Execute SARIMA com esses parâmetros\
# Verifique a validade do modelo usando gráficos de resíduos

# %%
from datetime import datetime

t1 = datetime.now()
t1
# Out:
# datetime.datetime(2022, 4, 29, 21, 5, 17, 754690)

# %%
from constantes import *

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from joblib import Parallel # Processamento paralelo
from multiprocessing import cpu_count
from joblib import delayed

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
#define function for kpss test
from statsmodels.tsa.stattools import kpss
#define KPSS
def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
      kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# #### Carregando os dados pré-processados para o modelo

# %%
filepath = "..\data\processed\CATEG_1.csv"
df = pd.read_csv(filepath).sort_values(by = ["DATE"])
df.head(3)
# Out:
#            DATE  UNITS_SOLD
# 510  2018-10-16           1
# 164  2019-06-11          27
# 514  2019-06-12          26

# %%
df = df[df["DATE"] > "2018-10-16"]
df['DATE'] = pd.to_datetime(df['DATE'])
df['UNITS_SOLD'] = df['UNITS_SOLD'].astype(float)
df.head(3)
# Out:
#           DATE  UNITS_SOLD
# 164 2019-06-11        27.0
# 514 2019-06-12        26.0
# 128 2019-06-13        24.0

# %%
df.isnull().sum()
df = df.dropna()
df.isnull().sum()
# Out:
# DATE          0
# UNITS_SOLD    0
# dtype: int64

# %%
df = df.set_index('DATE')

# %%
# ts_month_avg = df

# %% [markdown]
# #### Será definida uma reamostragem com medias semanais para a análise. Pois será mais expressiva a métrica de sazonalidade a seguir.

# %% [markdown]
# [dataframe.resample](https://www.geeksforgeeks.org/python-pandas-dataframe-resample/)

# %%
# reamostragem pela média semanal
ts_month_avg = df['UNITS_SOLD'].resample(f'{LAPSO_MEAN_1}D').mean()
ts_month_avg = ts_month_avg.dropna()
ts_month_avg = ts_month_avg.asfreq(f'{LAPSO_MEAN_1}D', method='ffill') # Incluindo uma configuração de frequência

# %%
L = len(ts_month_avg)
train_df = ts_month_avg[0:int(L*TRAINNG_DATA_PERCENTAGE_1)]
test_df = ts_month_avg[int(L*TRAINNG_DATA_PERCENTAGE_1):int(L*(TRAINNG_DATA_PERCENTAGE_1 + TEST_DATA_PERCENTAGE_1))]
validation_df = ts_month_avg[int(L*(TRAINNG_DATA_PERCENTAGE_1 + TEST_DATA_PERCENTAGE_1)):]

# %% [markdown]
# __Gráfico dos dados__

# %%
train_df.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# __Identificando Variação, Tendência e Sazonalidade nos dados__\
# Vamos verificar a tendência e os componentes sazonais dos dados. Cada série temporal pode ser decomposta em 3 componentes
#
# Tendência\
# Sazonalidade\
# Ruído
#
# Vamos ver nossa série temporal decomposta –

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 18
decomposition = sm.tsa.seasonal_decompose(train_df, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# Como podemos ver, há uma tendência de alta e uma sazonalidade semestral (6 x 4 semans por mês implica um lag = 24) nos dados. Portanto, a série não é estacionária. Temos que lidar com a sazonalidade analisar o efeito. Será realizada a diferenciação e será verificado o resultado por testes estatísticos como ADF (para tendência) e OSCB (para sazonalidade).
#
# Regra de polegar para testes estatísticos -
# ADF(para tendência): se o valor p for menor que o valor crítico, a série é estacionária
# OSCB(para sazonalidade): se o valor for menor que 0,64, a série é estacionária

# %%
LAGS = int(SAZONALITY_MONTHS_1*(30/LAPSO_MEAN_1))
LAGS = int(LAGS*LAG_REDUCTION_FACTOR_1)
LAGS
# Out:
# 12

# %%
print(adf_test(train_df))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.755787
# p-value                         0.064872
# #Lags Used                      0.000000
# Number of Observations Used    47.000000
# Critical Value (1%)            -3.577848
# Critical Value (5%)            -2.925338
# Critical Value (10%)           -2.600774
# dtype: float64
# None

# %% [markdown]
# Depois de executar o teste ADF na série temporal, obtemos  __p__ = __0.112672__ que é maior que o valor crítico de 0,05. Assim podemos confirmar estatisticamente que a série não é estacionária. Portanto, podemos realizar uma diferenciação de primeira ordem para a tendência e executamos novamente o teste ADF para verificar a estacionariedade.

# %%
rcParams['figure.figsize'] = 18, 8
ts_t_adj = train_df - train_df.shift(1)
ts_t_adj = ts_t_adj.dropna()
ts_t_adj.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
print(adf_test(ts_t_adj))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.434980e+00
# p-value                        1.826993e-13
# #Lags Used                     0.000000e+00
# Number of Observations Used    4.600000e+01
# Critical Value (1%)           -3.581258e+00
# Critical Value (5%)           -2.926785e+00
# Critical Value (10%)          -2.601541e+00
# dtype: float64
# None

# %% [markdown]
# Observando o __p-value__ a __tendência__ agora parece ter desaparecido. O valor p é menor que o valor crítico de 0,05. Portanto, podemos confirmar que a série agora é uma tendência estacionária.

# %% [markdown]
# Passemos agora para a diferenciação __sazonal__. Como os dados estão mostrando uma sazonalidade semestral, realizaremos uma diferenciação com defasagem 15 dias => 12 lags.

# %%
ts_s_adj = ts_t_adj - ts_t_adj.shift(LAGS)
ts_s_adj = ts_s_adj.dropna()
ts_s_adj.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# Agora que os dados estão estacionários, vamos para a próxima etapa do processo – os gráficos ACF e PACF.
#
# Parcelas ACF e PACF
#
# Vamos tentar descobrir os parâmetos do modelo
#
# Para descobrir isso , precisaríamos traçar os gráficos ACF e PACF.
#
# ACF significa Função de Correlação Automática e PACF significa Função de Correlação Automática Parcial.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_s_adj)
matplotlib.pyplot.show()
plot_pacf(ts_s_adj)
matplotlib.pyplot.show()

# %% [markdown]
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
#
# Os parâmetros para esses tipos de modelos são os seguintes:
#
# __p__ e sazonal __P__: indicam o número de termos AR (defasagens da série estacionária)\
# __d__ e sazonal __D__: indicam diferenciações que devem ser feitas para as séries tornarem-se estacionárias\
# __q__ e __Q__ sazonal: indicam o número de termos MA (lags dos erros da previsão)\
# __lag__: indica o intervalo da sazonalidade nos dados
#
# __Estimando termos de AR, ou p__
#
# O gráfico de pirulito que você vê acima são os resultados do ACF e do PACF. Para estimar a quantidade de termos AR, você precisa olhar para o gráfico PACF. Primeiro, ignore o valor na defasagem 0. Ele sempre mostrará uma correlação perfeita, pois estamos estimando a correlação entre o valor de hoje consigo mesmo. Observe que há uma área azul no gráfico, representando o intervalo de confiança. Para estimar quantos termos de AR você deve usar, comece a contar quantos “pirulito” estão acima ou abaixo do intervalo de confiança antes que o próximo entre na área azul.
#
# p = 1
#
#
# __Estimativa de termos I, ou d__
#
# Esta é uma parte fácil. Tudo o que você precisa fazer para estimar a quantidade de I(d) termos é saber quantas diferenciações foram usadas para tornar a série estacionária. Por exemplo, se você usou diferença logarítmica ou primeira diferença para transformar uma série temporal, a quantidade de termos I será 1, pois Arauto toma a diferença entre o valor real (por exemplo, o valor de hoje) e 1 valor anterior (por exemplo, o valor de ontem).
#
# d = 1
#
# __Estimando termos de MA, ou q__
#
# Assim como a função PACF, para estimar a quantidade de termos MA, desta vez você observará o gráfico ACF. A mesma lógica é aplicada aqui: quantos pirulitos estão acima ou abaixo do intervalo de confiança antes que o próximo pirulito entre na área azul?
#
# q = 1
#
# __Estimando termos sazonais de RA, ou P__
# Caso seus dados possuam sazonalidade e você queira utilizar um modelo Sazonal ARIMA, é necessário informar os termos sazonais para AR, I e MA. O processo é bastante semelhante ao AR não sazonal, e você ainda usará a função ACF e PACF para isso. Para estimar a quantidade de termos AR, você examinará mais uma vez a função PACF. Agora, em vez de contar quantos pirulitos estão fora do intervalo de confiança, você contará quantos pirulitos sazonais estão fora.
#
# Como os dados possuem sazonalidade semestral, é preciso verificar se o “pirulito” na defasagem 6 está fora da área do intervalo de confiança. Em caso de resultado positivo, é necessário adicionar 1 termo para AR Sazonal. Como temos um pirulito negativo na posição 6 adicionamos 1.
#
# P = 0
#
# __Estimating Seasonal I terms__
#
# A mesma lógica de estimar a diferenciação não sazonal é aplicada aqui. Se você usou a diferenciação sazonal para tornar a série temporal estacionária (por exemplo, o valor real (Yt) subtraído por 12 meses anteriores (Yt-12)), você adicionará 1 termo à diferenciação sazonal.
#
# D = 1
#
# __Estimating Seasonal MA terms__
#
# Para a média móvel sazonal (SMA), estaremos olhando para o gráfico ACF e usaremos a mesma lógica de estimar os termos SAR.
# Como só temos uma correlação forte em 4 temos, estimamos que o valor deve ser 0 ou 1.
#
# Q = 0
#
# lag = 18
#
# Portanto,
#
# $SARIMA(p,d,q)\times(P,D,Q)_{lag}$
# $SARIMA(0,1,0)\times(1,1,1)_{26}$

# %% [markdown]
# ### A seguir são realizadas algumas combinações de parâmetros para serem restados nas tentavas de otimizações a seguir utilizando a métrica AIC para a avaliação do modelo treinado.

# %%
pdq = [1, 1, 1]

# %%
pdq[1]
# Out:
# 1

# %%
p = range(0, 3)
d = range(0, 2)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = []
for x in list(itertools.product(p, d, q)):
    seasonal_pdq.append((x[0], x[1], x[2], LAGS) )

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
TOTAL_TEST = len(pdq)*len(seasonal_pdq)
print(f"Serão realizado {TOTAL_TEST} testes no total.")
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 0, 2, 12)
# SARIMAX: (0, 0, 2) x (0, 1, 0, 12)
# Serão realizado 324 testes no total.

# %% [markdown]
# ### A seguir é construído um script que testa combinações dos parâmetros e mede a métrica AIC para verificar qual a melhor combinação testada.

# %%
from operator import itemgetter
params_list = []
params_list_top = []
cont = 0
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_df,
                                            order= param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            # param = (1, 1, 1)
            cont +=1
            print(f"Teste {cont}/{TOTAL_TEST}")
            print('ARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            params_list.append([param, param_seasonal, results.aic])
            params_list_sort = []
            params_list_sort = sorted(params_list, key=itemgetter(2))
            params_list_sort_1 = params_list_sort[0]
            params_list_sort_2 = params_list_sort[2]
            params_list_sort_3 = params_list_sort[3]
            params_list_sort_4 = params_list_sort[4]
            params_list_sort_5 = params_list_sort[5]
            print(f'TOP 1 SARIMA params: {params_list_sort_1[0]}x{params_list_sort_1[1]} - AIC:{params_list_sort_1[2]}')
            print(f'TOP 2 SARIMA params: {params_list_sort_2[0]}x{params_list_sort_2[1]} - AIC:{params_list_sort_2[2]}')
            print(f'TOP 3 SARIMA params: {params_list_sort_3[0]}x{params_list_sort_3[1]} - AIC:{params_list_sort_3[2]}')
            print(f'TOP 4 SARIMA params: {params_list_sort_4[0]}x{params_list_sort_4[1]} - AIC:{params_list_sort_4[2]}')
            print(f'TOP 5 SARIMA params: {params_list_sort_5[0]}x{params_list_sort_5[1]} - AIC:{params_list_sort_5[2]}')
        except:
            continue

params_list_sort = []
params_list_sort = sorted(params_list, key=itemgetter(2))[0]
print(f'Best SARIMA params: {params_list_sort[0]}x{params_list_sort[1]} - AIC:{params_list_sort[2]}')
# Out:
# Optimization terminated successfully.
#          Current function value: 5.538958
#          Iterations: 1
#          Function evaluations: 26
# Teste 1/324
# ARIMA(0, 0, 0)x(0, 0, 0, 12) - AIC:533.7400069410955
# Optimization terminated successfully.
#          Current function value: 5.285599
#          Iterations: 4
#          Function evaluations: 98
# Teste 2/324
# ARIMA(0, 0, 0)x(0, 0, 1, 12) - AIC:511.4174974286549
# Optimization terminated successfully.
#          Current function value: 5.240345
#          Iterations: 4
#          Function evaluations: 220
# Teste 3/324
# ARIMA(0, 0, 0)x(0, 0, 2, 12) - AIC:509.0731297680612
# Optimization terminated successfully.
#          Current function value: 3.657712
#          Iterations: 2
#          Function evaluations: 36
# Teste 4/324
# ARIMA(0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# Optimization terminated successfully.
#          Current function value: 3.655049
#          Iterations: 2
#          Function evaluations: 56
# Teste 5/324
# ARIMA(0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# Optimization terminated successfully.
#          Current function value: 3.604893
#          Iterations: 3
#          Function evaluations: 119
# Teste 6/324
# ARIMA(0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# TOP 3 SARIMA params: (0, 0, 0)x(0, 0, 2, 12) - AIC:509.0731297680612
# TOP 4 SARIMA params: (0, 0, 0)x(0, 0, 1, 12) - AIC:511.4174974286549
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 0, 12) - AIC:533.7400069410955
# Optimization terminated successfully.
#          Current function value: 5.023849
#          Iterations: 2
#          Function evaluations: 56
# Teste 7/324
# ARIMA(0, 0, 0)x(1, 0, 0, 12) - AIC:486.289486931938
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# TOP 3 SARIMA params: (0, 0, 0)x(1, 0, 0, 12) - AIC:486.289486931938
# TOP 4 SARIMA params: (0, 0, 0)x(0, 0, 2, 12) - AIC:509.0731297680612
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 1, 12) - AIC:511.4174974286549
# Optimization terminated successfully.
#          Current function value: 5.022344
#          Iterations: 2
#          Function evaluations: 81
# Teste 8/324
# ARIMA(0, 0, 0)x(1, 0, 1, 12) - AIC:488.1449861593011
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# TOP 3 SARIMA params: (0, 0, 0)x(1, 0, 0, 12) - AIC:486.289486931938
# TOP 4 SARIMA params: (0, 0, 0)x(1, 0, 1, 12) - AIC:488.1449861593011
# TOP 5 SARIMA params: (0, 0, 0)x(0, 0, 2, 12) - AIC:509.0731297680612
# Optimization terminated successfully.
#          Current function value: 4.967614
#          Iterations: 6
#          Function evaluations: 294
# Teste 9/324
# ARIMA(0, 0, 0)x(1, 0, 2, 12) - AIC:484.8909281833495
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# TOP 3 SARIMA params: (0, 0, 0)x(1, 0, 2, 12) - AIC:484.8909281833495
# TOP 4 SARIMA params: (0, 0, 0)x(1, 0, 0, 12) - AIC:486.289486931938
# TOP 5 SARIMA params: (0, 0, 0)x(1, 0, 1, 12) - AIC:488.1449861593011
# Optimization terminated successfully.
#          Current function value: 3.652884
#          Iterations: 2
#          Function evaluations: 42
# Teste 10/324
# ARIMA(0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# TOP 4 SARIMA params: (0, 0, 0)x(1, 0, 2, 12) - AIC:484.8909281833495
# TOP 5 SARIMA params: (0, 0, 0)x(1, 0, 0, 12) - AIC:486.289486931938
# Optimization terminated successfully.
#          Current function value: 3.626623
#          Iterations: 12
#          Function evaluations: 461
# Teste 11/324
# ARIMA(0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# TOP 5 SARIMA params: (0, 0, 0)x(1, 0, 2, 12) - AIC:484.8909281833495
# Optimization terminated successfully.
#          Current function value: 3.604496
#          Iterations: 3
#          Function evaluations: 152
# Teste 12/324
# ARIMA(0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# Optimization terminated successfully.
#          Current function value: 5.020801
#          Iterations: 2
#          Function evaluations: 76
# Teste 13/324
# ARIMA(0, 0, 0)x(2, 0, 0, 12) - AIC:487.99693797673393
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# Optimization terminated successfully.
#          Current function value: 5.020366
#          Iterations: 2
#          Function evaluations: 103
# Teste 14/324
# ARIMA(0, 0, 0)x(2, 0, 1, 12) - AIC:489.9551570577759
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# Optimization terminated successfully.
#          Current function value: 4.966665
#          Iterations: 7
#          Function evaluations: 409
# Teste 15/324
# ARIMA(0, 0, 0)x(2, 0, 2, 12) - AIC:486.7998372595748
# TOP 1 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 2 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 1, 12) - AIC:354.8846707888904
# Optimization terminated successfully.
#          Current function value: 3.603826
#          Iterations: 4
#          Function evaluations: 135
# Teste 16/324
# ARIMA(0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 3 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 0, 12) - AIC:354.6768304956264
# Optimization terminated successfully.
#          Current function value: 3.603826
#          Iterations: 2
#          Function evaluations: 98
# Teste 17/324
# ARIMA(0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# Optimization terminated successfully.
#          Current function value: 3.603826
#          Iterations: 2
#          Function evaluations: 121
# Teste 18/324
# ARIMA(0, 0, 0)x(2, 1, 2, 12) - AIC:355.9673338325819
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# Optimization terminated successfully.
#          Current function value: 5.139877
#          Iterations: 2
#          Function evaluations: 52
# Teste 19/324
# ARIMA(0, 0, 1)x(0, 0, 0, 12) - AIC:497.4281559201688
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# Optimization terminated successfully.
#          Current function value: 5.049602
#          Iterations: 4
#          Function evaluations: 151
# Teste 20/324
# ARIMA(0, 0, 1)x(0, 0, 1, 12) - AIC:490.7618347863047
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# Optimization terminated successfully.
#          Current function value: 4.874290
#          Iterations: 7
#          Function evaluations: 351
# Teste 21/324
# ARIMA(0, 0, 1)x(0, 0, 2, 12) - AIC:475.93179436238677
# TOP 1 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# TOP 4 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 1, 12) - AIC:354.1558133038671
# Optimization terminated successfully.
#          Current function value: 3.621870
#          Iterations: 1
#          Function evaluations: 23
# Teste 22/324
# ARIMA(0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 2 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# TOP 5 SARIMA params: (0, 0, 0)x(1, 1, 2, 12) - AIC:354.03164357515493
# Optimization terminated successfully.
#          Current function value: 3.596654
#          Iterations: 3
#          Function evaluations: 117
# Teste 23/324
# ARIMA(0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 2 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 3 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 1, 12) - AIC:353.9672848992441
# Optimization terminated successfully.
#          Current function value: 3.529611
#          Iterations: 5
#          Function evaluations: 237
# Teste 24/324
# ARIMA(0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# Optimization terminated successfully.
#          Current function value: 4.904290
#          Iterations: 4
#          Function evaluations: 156
# Teste 25/324
# ARIMA(0, 0, 1)x(1, 0, 0, 12) - AIC:476.81188588663804
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# Optimization terminated successfully.
#          Current function value: 4.871060
#          Iterations: 6
#          Function evaluations: 299
# Teste 26/324
# ARIMA(0, 0, 1)x(1, 0, 1, 12) - AIC:475.62174566463796
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# Optimization terminated successfully.
#          Current function value: 4.794463
#          Iterations: 7
#          Function evaluations: 438
# Teste 27/324
# ARIMA(0, 0, 1)x(1, 0, 2, 12) - AIC:470.2684864862132
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 3 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 4 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 0, 12) - AIC:353.14032241738704
# Optimization terminated successfully.
#          Current function value: 3.560157
#          Iterations: 4
#          Function evaluations: 148
# Teste 28/324
# ARIMA(0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# TOP 1 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 3 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 4 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# TOP 5 SARIMA params: (0, 0, 0)x(0, 1, 2, 12) - AIC:352.06976234071004
# Optimization terminated successfully.
#          Current function value: 3.512466
#          Iterations: 8
#          Function evaluations: 374
# Teste 29/324
# ARIMA(0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 1 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# TOP 3 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# TOP 5 SARIMA params: (0, 0, 0)x(2, 1, 0, 12) - AIC:351.9673259841236
# Optimization terminated successfully.
#          Current function value: 3.503405
#          Iterations: 6
#          Function evaluations: 357
# Teste 30/324
# ARIMA(0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 1 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# Optimization terminated successfully.
#          Current function value: 4.815986
#          Iterations: 6
#          Function evaluations: 301
# Teste 31/324
# ARIMA(0, 0, 1)x(2, 0, 0, 12) - AIC:470.33461701303577
# TOP 1 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# Optimization terminated successfully.
#          Current function value: 4.762279
#          Iterations: 11
#          Function evaluations: 659
# Teste 32/324
# ARIMA(0, 0, 1)x(2, 0, 1, 12) - AIC:467.1787698763517
# TOP 1 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# Optimization terminated successfully.
#          Current function value: 4.751260
#          Iterations: 8
#          Function evaluations: 578
# Teste 33/324
# ARIMA(0, 0, 1)x(2, 0, 2, 12) - AIC:468.1209390422963
# TOP 1 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 2 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 0, 12) - AIC:351.6994933051789
# Optimization terminated successfully.
#          Current function value: 3.503641
#          Iterations: 5
#          Function evaluations: 231
# Teste 34/324
# ARIMA(0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 3 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 1, 12) - AIC:351.27875280690387
# Optimization terminated successfully.
#          Current function value: 3.503420
#          Iterations: 4
#          Function evaluations: 227
# Teste 35/324
# ARIMA(0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# Optimization terminated successfully.
#          Current function value: 3.503409
#          Iterations: 4
#          Function evaluations: 274
# Teste 36/324
# ARIMA(0, 0, 1)x(2, 1, 2, 12) - AIC:348.3272376429479
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# Optimization terminated successfully.
#          Current function value: 4.808405
#          Iterations: 4
#          Function evaluations: 152
# Teste 37/324
# ARIMA(0, 0, 2)x(0, 0, 0, 12) - AIC:467.60684254446244
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# Optimization terminated successfully.
#          Current function value: 4.793956
#          Iterations: 3
#          Function evaluations: 146
# Teste 38/324
# ARIMA(0, 0, 2)x(0, 0, 1, 12) - AIC:468.2197950789607
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# Optimization terminated successfully.
#          Current function value: 4.635842
#          Iterations: 7
#          Function evaluations: 430
# Teste 39/324
# ARIMA(0, 0, 2)x(0, 0, 2, 12) - AIC:455.0408436904585
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# Optimization terminated successfully.
#          Current function value: 3.576736
#          Iterations: 2
#          Function evaluations: 66
# Teste 40/324
# ARIMA(0, 0, 2)x(0, 1, 0, 12) - AIC:349.3666622707792
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 4 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 0, 12) - AIC:347.7750734386068
# Optimization terminated successfully.
#          Current function value: 3.512481
#          Iterations: 4
#          Function evaluations: 184
# Teste 41/324
# ARIMA(0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# TOP 1 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# TOP 5 SARIMA params: (0, 0, 1)x(0, 1, 2, 12) - AIC:346.8426264279911
# Optimization terminated successfully.
#          Current function value: 3.448499
#          Iterations: 7
#          Function evaluations: 416
# Teste 42/324
# ARIMA(0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# Optimization terminated successfully.
#          Current function value: 4.737810
#          Iterations: 6
#          Function evaluations: 284
# Teste 43/324
# ARIMA(0, 0, 2)x(1, 0, 0, 12) - AIC:462.8297840708891
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# Optimization terminated successfully.
#          Current function value: 4.685122
#          Iterations: 9
#          Function evaluations: 523
# Teste 44/324
# ARIMA(0, 0, 2)x(1, 0, 1, 12) - AIC:459.771677666298
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# Optimization terminated successfully.
#          Current function value: 4.608398
#          Iterations: 7
#          Function evaluations: 501
# Teste 45/324
# ARIMA(0, 0, 2)x(1, 0, 2, 12) - AIC:454.40618419211256
# TOP 1 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 2 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 1, 12) - AIC:346.3283343561428
# Optimization terminated successfully.
#          Current function value: 3.443787
#          Iterations: 4
#          Function evaluations: 177
# Teste 46/324
# ARIMA(0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 2 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 3 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 2, 12) - AIC:346.3269263183792
# Optimization terminated successfully.
#          Current function value: 3.403532
#          Iterations: 9
#          Function evaluations: 526
# Teste 47/324
# ARIMA(0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 2 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 3 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 4 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# TOP 5 SARIMA params: (0, 0, 2)x(0, 1, 1, 12) - AIC:345.19817612796805
# Optimization terminated successfully.
#          Current function value: 3.403451
#          Iterations: 5
#          Function evaluations: 345
# Teste 48/324
# ARIMA(0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# Optimization terminated successfully.
#          Current function value: 4.604021
#          Iterations: 6
#          Function evaluations: 362
# Teste 49/324
# ARIMA(0, 0, 2)x(2, 0, 0, 12) - AIC:451.98606113570213
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# Optimization terminated successfully.
#          Current function value: 4.565793
#          Iterations: 10
#          Function evaluations: 713
# Teste 50/324
# ARIMA(0, 0, 2)x(2, 0, 1, 12) - AIC:450.3161257507628
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# Optimization terminated successfully.
#          Current function value: 4.562750
#          Iterations: 8
#          Function evaluations: 663
# Teste 51/324
# ARIMA(0, 0, 2)x(2, 0, 2, 12) - AIC:452.0239660533571
# TOP 1 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 3 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 4 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# TOP 5 SARIMA params: (0, 0, 1)x(1, 1, 1, 12) - AIC:345.1967323762435
# Optimization terminated successfully.
#          Current function value: 3.403148
#          Iterations: 6
#          Function evaluations: 336
# Teste 52/324
# ARIMA(0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 1 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 4 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# TOP 5 SARIMA params: (0, 0, 1)x(2, 1, 0, 12) - AIC:344.3494897925316
# Optimization terminated successfully.
#          Current function value: 3.402997
#          Iterations: 4
#          Function evaluations: 274
# Teste 53/324
# ARIMA(0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 1 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 5 SARIMA params: (0, 0, 2)x(0, 1, 2, 12) - AIC:341.05592049672856
# Optimization terminated successfully.
#          Current function value: 3.402947
#          Iterations: 4
#          Function evaluations: 321
# Teste 54/324
# ARIMA(0, 0, 2)x(2, 1, 2, 12) - AIC:340.68287361288674
# TOP 1 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 2, 12) - AIC:340.68287361288674
# Optimization terminated successfully.
#          Current function value: 4.392310
#          Iterations: 1
#          Function evaluations: 10
# Teste 55/324
# ARIMA(0, 1, 0)x(0, 0, 0, 12) - AIC:423.6617967310317
# TOP 1 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 2, 12) - AIC:340.68287361288674
# Optimization terminated successfully.
#          Current function value: 4.370864
#          Iterations: 2
#          Function evaluations: 47
# Teste 56/324
# ARIMA(0, 1, 0)x(0, 0, 1, 12) - AIC:423.60291923958493
# TOP 1 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 2, 12) - AIC:340.68287361288674
# Optimization terminated successfully.
#          Current function value: 4.211588
#          Iterations: 6
#          Function evaluations: 214
# Teste 57/324
# ARIMA(0, 1, 0)x(0, 0, 2, 12) - AIC:410.3124384814466
# TOP 1 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 2, 12) - AIC:340.68287361288674
# Optimization terminated successfully.
#          Current function value: 3.619359
#          Iterations: 2
#          Function evaluations: 38
# Teste 58/324
# ARIMA(0, 1, 0)x(0, 1, 0, 12) - AIC:349.4584179182168
# TOP 1 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 2, 12) - AIC:340.68287361288674
# Optimization terminated successfully.
#          Current function value: 3.417901
#          Iterations: 5
#          Function evaluations: 135
# Teste 59/324
# ARIMA(0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 2 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 4 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 2, 12) - AIC:338.7313214100827
# Optimization terminated successfully.
#          Current function value: 3.300289
#          Iterations: 6
#          Function evaluations: 235
# Teste 60/324
# ARIMA(0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 2 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# Optimization terminated successfully.
#          Current function value: 4.347975
#          Iterations: 2
#          Function evaluations: 49
# Teste 61/324
# ARIMA(0, 1, 0)x(1, 0, 0, 12) - AIC:421.4055961845525
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 2 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# Optimization terminated successfully.
#          Current function value: 4.260154
#          Iterations: 9
#          Function evaluations: 335
# Teste 62/324
# ARIMA(0, 1, 0)x(1, 0, 1, 12) - AIC:414.9747838523585
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 2 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# Optimization terminated successfully.
#          Current function value: 4.178495
#          Iterations: 6
#          Function evaluations: 281
# Teste 63/324
# ARIMA(0, 1, 0)x(1, 0, 2, 12) - AIC:409.1355129650166
# TOP 1 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 2 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 3 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 1, 12) - AIC:338.6877556500327
# Optimization terminated successfully.
#          Current function value: 3.201811
#          Iterations: 2
#          Function evaluations: 59
# Teste 64/324
# ARIMA(0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 3 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 4 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 0, 12) - AIC:338.60355424423324
# Optimization terminated successfully.
#          Current function value: 3.198366
#          Iterations: 4
#          Function evaluations: 155
# Teste 65/324
# ARIMA(0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 3 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 4 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# TOP 5 SARIMA params: (0, 0, 2)x(1, 1, 1, 12) - AIC:336.7391078438776
# Optimization terminated successfully.
#          Current function value: 3.198089
#          Iterations: 4
#          Function evaluations: 203
# Teste 66/324
# ARIMA(0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 3 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# Optimization terminated successfully.
#          Current function value: 4.154004
#          Iterations: 2
#          Function evaluations: 76
# Teste 67/324
# ARIMA(0, 1, 0)x(2, 0, 0, 12) - AIC:404.7843969513088
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 3 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# Optimization terminated successfully.
#          Current function value: 4.154103
#          Iterations: 2
#          Function evaluations: 98
# Teste 68/324
# ARIMA(0, 1, 0)x(2, 0, 1, 12) - AIC:406.79393111272424
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 3 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# Optimization terminated successfully.
#          Current function value: 4.154531
#          Iterations: 3
#          Function evaluations: 178
# Teste 69/324
# ARIMA(0, 1, 0)x(2, 0, 2, 12) - AIC:408.83500756863094
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 3 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# TOP 5 SARIMA params: (0, 0, 2)x(2, 1, 0, 12) - AIC:336.70225201824877
# Optimization terminated successfully.
#          Current function value: 3.197350
#          Iterations: 3
#          Function evaluations: 112
# Teste 70/324
# ARIMA(0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 4 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 1, 12) - AIC:332.118536385002
# Optimization terminated successfully.
#          Current function value: 3.197458
#          Iterations: 4
#          Function evaluations: 200
# Teste 71/324
# ARIMA(0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(0, 1, 2, 12) - AIC:322.82770371262353
# Optimization terminated successfully.
#          Current function value: 3.197361
#          Iterations: 4
#          Function evaluations: 248
# Teste 72/324
# ARIMA(0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 4.366859
#          Iterations: 2
#          Function evaluations: 47
# Teste 73/324
# ARIMA(0, 1, 1)x(0, 0, 0, 12) - AIC:423.2184247907016
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 4.360332
#          Iterations: 3
#          Function evaluations: 112
# Teste 74/324
# ARIMA(0, 1, 1)x(0, 0, 1, 12) - AIC:424.5919111275103
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 4.206130
#          Iterations: 6
#          Function evaluations: 286
# Teste 75/324
# ARIMA(0, 1, 1)x(0, 0, 2, 12) - AIC:411.7885020893191
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 3.487838
#          Iterations: 3
#          Function evaluations: 76
# Teste 76/324
# ARIMA(0, 1, 1)x(0, 1, 0, 12) - AIC:338.8324454446133
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 3.344127
#          Iterations: 5
#          Function evaluations: 189
# Teste 77/324
# ARIMA(0, 1, 1)x(0, 1, 1, 12) - AIC:327.03617464396245
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 3.259970
#          Iterations: 7
#          Function evaluations: 342
# Teste 78/324
# ARIMA(0, 1, 1)x(0, 1, 2, 12) - AIC:320.9571362340948
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 4.347389
#          Iterations: 3
#          Function evaluations: 112
# Teste 79/324
# ARIMA(0, 1, 1)x(1, 0, 0, 12) - AIC:423.3493653369022
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 4.259024
#          Iterations: 12
#          Function evaluations: 574
# Teste 80/324
# ARIMA(0, 1, 1)x(1, 0, 1, 12) - AIC:416.8662905991589
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 4.178415
#          Iterations: 7
#          Function evaluations: 413
# Teste 81/324
# ARIMA(0, 1, 1)x(1, 0, 2, 12) - AIC:411.1278094773234
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 2, 12) - AIC:316.9466599664123
# Optimization terminated successfully.
#          Current function value: 3.191396
#          Iterations: 5
#          Function evaluations: 174
# Teste 82/324
# ARIMA(0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# TOP 5 SARIMA params: (0, 1, 0)x(1, 1, 2, 12) - AIC:315.01655105813404
# Optimization terminated successfully.
#          Current function value: 3.189148
#          Iterations: 5
#          Function evaluations: 240
# Teste 83/324
# ARIMA(0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# Optimization terminated successfully.
#          Current function value: 3.188610
#          Iterations: 5
#          Function evaluations: 297
# Teste 84/324
# ARIMA(0, 1, 1)x(1, 1, 2, 12) - AIC:316.10657568130546
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# Optimization terminated successfully.
#          Current function value: 4.153604
#          Iterations: 4
#          Function evaluations: 186
# Teste 85/324
# ARIMA(0, 1, 1)x(2, 0, 0, 12) - AIC:406.74594177093604
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# Optimization terminated successfully.
#          Current function value: 4.153768
#          Iterations: 4
#          Function evaluations: 229
# Teste 86/324
# ARIMA(0, 1, 1)x(2, 0, 1, 12) - AIC:408.7617027546785
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# Optimization terminated successfully.
#          Current function value: 4.153753
#          Iterations: 4
#          Function evaluations: 279
# Teste 87/324
# ARIMA(0, 1, 1)x(2, 0, 2, 12) - AIC:410.76031925837555
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# TOP 5 SARIMA params: (0, 1, 0)x(2, 1, 1, 12) - AIC:314.9559930455962
# Optimization terminated successfully.
#          Current function value: 3.188097
#          Iterations: 5
#          Function evaluations: 230
# Teste 88/324
# ARIMA(0, 1, 1)x(2, 1, 0, 12) - AIC:314.0572970623676
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(2, 1, 0, 12) - AIC:314.0572970623676
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# Optimization terminated successfully.
#          Current function value: 3.188107
#          Iterations: 5
#          Function evaluations: 298
# Teste 89/324
# ARIMA(0, 1, 1)x(2, 1, 1, 12) - AIC:316.05825369300766
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(2, 1, 0, 12) - AIC:314.0572970623676
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# Optimization terminated successfully.
#          Current function value: 3.188098
#          Iterations: 5
#          Function evaluations: 353
# Teste 90/324
# ARIMA(0, 1, 1)x(2, 1, 2, 12) - AIC:318.0573809055845
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 3 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 4 SARIMA params: (0, 1, 1)x(2, 1, 0, 12) - AIC:314.0572970623676
# TOP 5 SARIMA params: (0, 1, 1)x(1, 1, 1, 12) - AIC:314.1581851524037
# Optimization terminated successfully.
#          Current function value: 4.361193
#          Iterations: 2
#          Function evaluations: 67
# ...
# Teste 296/324
# ARIMA(2, 1, 1)x(1, 0, 1, 12) - AIC:418.8633259859967
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.168890
#          Iterations: 7
#          Function evaluations: 570
# Teste 297/324
# ARIMA(2, 1, 1)x(1, 0, 2, 12) - AIC:414.2134525915774
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.188142
#          Iterations: 6
#          Function evaluations: 364
# Teste 298/324
# ARIMA(2, 1, 1)x(1, 1, 0, 12) - AIC:316.0616450245738
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.179436
#          Iterations: 9
#          Function evaluations: 655
# Teste 299/324
# ARIMA(2, 1, 1)x(1, 1, 1, 12) - AIC:317.22584580241823
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.177072
#          Iterations: 12
#          Function evaluations: 1009
# Teste 300/324
# ARIMA(2, 1, 1)x(1, 1, 2, 12) - AIC:318.99887812904007
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.149270
#          Iterations: 4
#          Function evaluations: 277
# Teste 301/324
# ARIMA(2, 1, 1)x(2, 0, 0, 12) - AIC:410.32988074589184
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.149450
#          Iterations: 4
#          Function evaluations: 317
# Teste 302/324
# ARIMA(2, 1, 1)x(2, 0, 1, 12) - AIC:412.3472010869839
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.149334
#          Iterations: 4
#          Function evaluations: 368
# Teste 303/324
# ARIMA(2, 1, 1)x(2, 0, 2, 12) - AIC:414.3360636748147
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.181973
#          Iterations: 5
#          Function evaluations: 362
# Teste 304/324
# ARIMA(2, 1, 1)x(2, 1, 0, 12) - AIC:317.4693715456282
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.177946
#          Iterations: 7
#          Function evaluations: 580
# Teste 305/324
# ARIMA(2, 1, 1)x(2, 1, 1, 12) - AIC:319.0828306953292
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.177647
#          Iterations: 8
#          Function evaluations: 759
# Teste 306/324
# ARIMA(2, 1, 1)x(2, 1, 2, 12) - AIC:321.0540763876638
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.319691
#          Iterations: 4
#          Function evaluations: 241
# Teste 307/324
# ARIMA(2, 1, 2)x(0, 0, 0, 12) - AIC:424.6903651061871
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.315319
#          Iterations: 4
#          Function evaluations: 286
# Teste 308/324
# ARIMA(2, 1, 2)x(0, 0, 1, 12) - AIC:426.27060890035244
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.181830
#          Iterations: 5
#          Function evaluations: 424
# Teste 309/324
# ARIMA(2, 1, 2)x(0, 0, 2, 12) - AIC:415.45568918506825
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.470440
#          Iterations: 3
#          Function evaluations: 177
# Teste 310/324
# ARIMA(2, 1, 2)x(0, 1, 0, 12) - AIC:343.1622462158532
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.333987
#          Iterations: 5
#          Function evaluations: 357
# Teste 311/324
# ARIMA(2, 1, 2)x(0, 1, 1, 12) - AIC:332.0627072998
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.239193
#          Iterations: 8
#          Function evaluations: 680
# Teste 312/324
# ARIMA(2, 1, 2)x(0, 1, 2, 12) - AIC:324.9625012988582
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.310003
#          Iterations: 5
#          Function evaluations: 367
# Teste 313/324
# ARIMA(2, 1, 2)x(1, 0, 0, 12) - AIC:425.760269438052
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.250661
#          Iterations: 11
#          Function evaluations: 915
# Teste 314/324
# ARIMA(2, 1, 2)x(1, 0, 1, 12) - AIC:422.0634513061735
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.149840
#          Iterations: 7
#          Function evaluations: 673
# Teste 315/324
# ARIMA(2, 1, 2)x(1, 0, 2, 12) - AIC:414.38462413686267
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.187589
#          Iterations: 6
#          Function evaluations: 435
# Teste 316/324
# ARIMA(2, 1, 2)x(1, 1, 0, 12) - AIC:318.00854100849637
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.183380
#          Iterations: 5
#          Function evaluations: 427
# Teste 317/324
# ARIMA(2, 1, 2)x(1, 1, 1, 12) - AIC:319.60445383779575
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.183041
#          Iterations: 6
#          Function evaluations: 584
# Teste 318/324
# ARIMA(2, 1, 2)x(1, 1, 2, 12) - AIC:321.57193867551626
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.131220
#          Iterations: 7
#          Function evaluations: 593
# Teste 319/324
# ARIMA(2, 1, 2)x(2, 0, 0, 12) - AIC:410.59708139728775
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.130811
#          Iterations: 6
#          Function evaluations: 575
# Teste 320/324
# ARIMA(2, 1, 2)x(2, 0, 1, 12) - AIC:412.5578345068801
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 4.129694
#          Iterations: 6
#          Function evaluations: 644
# Teste 321/324
# ARIMA(2, 1, 2)x(2, 0, 2, 12) - AIC:414.45062645899213
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.178505
#          Iterations: 7
#          Function evaluations: 578
# Teste 322/324
# ARIMA(2, 1, 2)x(2, 1, 0, 12) - AIC:319.13644488454884
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.182780
#          Iterations: 6
#          Function evaluations: 579
# Teste 323/324
# ARIMA(2, 1, 2)x(2, 1, 1, 12) - AIC:321.5468546580827
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Optimization terminated successfully.
#          Current function value: 3.182615
#          Iterations: 5
#          Function evaluations: 537
# Teste 324/324
# ARIMA(2, 1, 2)x(2, 1, 2, 12) - AIC:323.5310846400205
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Best SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216

# %% [markdown]
# ````
# Teste 324/324
# ARIMA(2, 1, 2)x(2, 1, 2, 12) - AIC:323.5310846400205
# TOP 1 SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
# TOP 2 SARIMA params: (0, 1, 1)x(1, 1, 0, 12) - AIC:312.3740409143702
# TOP 3 SARIMA params: (0, 1, 0)x(2, 1, 0, 12) - AIC:312.94559013459457
# TOP 4 SARIMA params: (0, 1, 0)x(1, 1, 1, 12) - AIC:313.04317131854475
# TOP 5 SARIMA params: (1, 1, 0)x(2, 1, 0, 12) - AIC:313.8417895403543
# Best SARIMA params: (0, 1, 0)x(1, 1, 0, 12) - AIC:311.37389836449216
#  ````

# %%
mod = sm.tsa.statespace.SARIMAX(train_df,
                                order=params_list_sort[0], # Best paramns
                                seasonal_order=params_list_sort[1]) # Best paramns
results = mod.fit(method = 'powell')
print(results.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 3.201811
#          Iterations: 2
#          Function evaluations: 59
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.9196      0.061    -15.128      0.000      -1.039      -0.800
# sigma2       199.3130     63.347      3.146      0.002      75.156     323.470
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
START_TIME_PREDICTION = train_df.index.max()
START_TIME_PREDICTION
# Out:
# Timestamp('2021-05-16 00:00:00', freq='15D')

# %%
import datetime
END_TIME_PREDICTION = validation_df.index.max() + datetime.timedelta(days=+120)
END_TIME_PREDICTION
# Out:
# Timestamp('2022-03-12 00:00:00', freq='15D')

# %%
pred = results.get_prediction(start=START_TIME_PREDICTION, dynamic=True, end=END_TIME_PREDICTION)
pred_ci = pred.conf_int(alpha=0.05)
ax = ts_month_avg.plot(label='Dados Originais', color = "blue")
ax = train_df.plot(label='Dados Treino', color = "green")
pred.predicted_mean.plot(ax=ax, label='Previsão', alpha=.7, figsize=(14, 4), color = "red")
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('DATE')
ax.set_ylabel('UNITS_SOLD')
plt.ylim([25, 75])

TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS = 6

TIME_INTERAVAL_TO_OBSERVE = TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS*7
 
plt.xlim([START_TIME_PREDICTION + datetime.timedelta(days=-TIME_INTERAVAL_TO_OBSERVE/8), START_TIME_PREDICTION + datetime.timedelta(days=TIME_INTERAVAL_TO_OBSERVE)])
plt.title(f"Previsão para {TIME_INTERAVAL_TO_OBSERVE_IN_WEEKS} semanas.")
plt.legend()
plt.show()

# %%
from datetime import datetime
t2 = datetime.now()
dt = t2 - t1
print(f"O tempo total para rodar o sript foi de {dt}")
# Out:
# O tempo total para rodar o sript foi de 0:22:20.858424
