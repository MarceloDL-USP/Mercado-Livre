# %%
import pandas as pd

# %%
path = "..\data\external\ordenamiento.csv"
df = pd.read_csv(path)
df
# Out:
#         item_id         vertical              category  \
# 0     512208310              CPG             PETS FOOD
# 1     468513076               CE           ELECTRONICS
# 2     614337410               CE           ELECTRONICS
# 3     634351318     APP & SPORTS               APPAREL
# 4     528383704              ACC  VEHICULAR MULTIMEDIA
# ...         ...              ...                   ...
# 4995  621100365  HOME & INDUSTRY            HOME&DECOR
# 4996  613555182  BEAUTY & HEALTH         PHARMACEUTICS
# 4997  535350054  HOME & INDUSTRY            STATIONARY
# 4998  549193472  HOME & INDUSTRY            HOME&DECOR
# 4999  580229494               CE           ELECTRONICS
#
#                               domain   score
# 0            MLC-CATS_AND_DOGS_FOODS  0.0272
# 1                         MLC-RANGES  0.9256
# 2                 MLC-SMART_SPEAKERS  0.8304
# 3                          MLC-PANTS  0.0560
# 4                            MLC-GPS  0.2334
# ...
